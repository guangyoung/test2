# %% [markdown]
# <a href="https://colab.research.google.com/github/guangyoung/test2/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

from bokeh.io import curdoc, show
from bokeh.layouts import column, row
from bokeh.models import ColumnDataSource, CustomJS, Slider, TextInput, DatePicker, PasswordInput, NumericInput, Select, MultiSelect, Button, DataTable, DateFormatter, TableColumn, PreText, Div, TabPanel, Tabs
from bokeh.plotting import figure
from datetime import date
from random import randint

# Set up data
N = 200
x = np.linspace(0, 4*np.pi, N)
y = np.sin(x)
source = ColumnDataSource(data=dict(x=x, y=y))


# Set up plot
# plot = figure(height=285, width=350, title="my sine wave",
#               tools="crosshair,pan,reset,save,wheel_zoom",
#               x_range=[0, 4*np.pi], y_range=[-2.5, 2.5])

# plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)


# Set up widgets
# text = PreText(text="""QUANTZENIUS""", width=100, height=12)
text1 = Div(text="""<img src="https://raw.githubusercontent.com/guangyoung/test2/main/logo_quantxi1.png" width="200" height="40" alt="div_image">""")
text2 = Div(text="""<img src="https://raw.githubusercontent.com/guangyoung/test2/main/systemtesting.png" width="200" height="40" alt="div_image">""")
api_key = PasswordInput(title="API Key", placeholder="enter your api key...")
initial_equity = NumericInput(title="Initial Equity", value=1000000, low=-1000000, high=100000000)
spread_slippage = NumericInput(title="Spread+Slippage", value=0.001, low=0.001, high=0.05)
commision = NumericInput(title="Commision", value=0.001, low=0.001, high=0.05)
interest = NumericInput(title="Interest", value=0.001, low=0.001, high=0.05)
data_source = Select(title="Select Data Source:", value="EOD Historical Data", options=["EOD Historical Data", "Tiingo", "Alpha Vantage", "Twelve Data"], width=200)
exchange = Select(title="Select Exchange:", value="Nasdaq", options=["Nasdaq", "NYSE", "LSE", "Dow"], width=200)
OPTIONS = [("1", "foo"), ("2", "bar"), ("3", "baz"), ("4", "quux")]
portfolio = MultiSelect(title="Select Stock:", value=["1", "2"], options= OPTIONS, height=130, width=200)
create_testdata = Button(label="Create Testdata", button_type="success")
date_picker = DatePicker(
    title="Select date",
    value="2019-09-20",
    min_date="2019-08-01",
    max_date="2019-10-30",
)

pre = PreText(text="""TESTDATA""", width=100, height=12)

data = dict(
        dates=[date(2014, 3, i+1) for i in range(20)],
        downloads=[randint(0, 100) for i in range(20)],
    )
source = ColumnDataSource(data)

columns = [
        TableColumn(field="dates", title="Date", formatter=DateFormatter()),
        TableColumn(field="downloads", title="Downloads"),
    ]
data_table = DataTable(source=source, columns=columns, width=600, height=268)

p1 = figure(width=500, height=240)
p1.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=20, color="navy", alpha=0.5)
tab1 = TabPanel(child=p1, title="Total Return")

p2 = figure(width=500, height=240)
p2.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], line_width=3, color="navy", alpha=0.5)
tab2 = TabPanel(child=p2, title="CAGR")

p3 = figure(width=500, height=240)
p3.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], line_width=3, color="navy", alpha=0.5)
tab3 = TabPanel(child=p3, title="Max DD")

p4 = figure(width=500, height=240)
p4.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], line_width=3, color="navy", alpha=0.5)
tab4 = TabPanel(child=p4, title="Sharpe")

tt = Tabs(tabs=[tab1, tab2, tab3, tab4])
# date_picker.js_on_change("value", CustomJS(code="""
#     console.log("date_picker: value=" + this.value, this.toString())
# """))

# show(date_picker)


# Set up callbacks
# def update_title(attrname, old, new):
#     plot.title.text = text.value

# text.on_change('value', update_title)

# def update_data(attrname, old, new):

#     # Get the current slider values
#     a = amplitude.value
#     b = offset.value
#     w = phase.value
#     k = freq.value

#     # Generate the new curve
#     x = np.linspace(0, 4*np.pi, N)
#     y = a*np.sin(k*x + w) + b

#     source.data = dict(x=x, y=y)

# for w in [offset, amplitude, phase, freq]:
#     w.on_change('value', update_data)


# Set up layouts and add to document
inputs1 = column(api_key, initial_equity, spread_slippage, commision, interest)
inputs2 = column(data_source, exchange, portfolio, create_testdata)
inputs3 = column(pre, data_table)

curdoc().theme = 'dark_minimal'
curdoc().add_root(row(text1, text2, width=1360, background="darkslategray"))
curdoc().add_root(row(inputs1, inputs2, inputs3, width=1360, background="gray"))
curdoc().add_root(row(tt, width=1360, height=300, background="deepskyblue"))
curdoc().title = "Sliders"
