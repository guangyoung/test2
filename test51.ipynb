# %% [markdown]
# <a href="https://colab.research.google.com/github/guangyoung/test2/blob/main/test51.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import requests
from urllib3 import PoolManager
from cachecontrol import CacheControl
# from cachecontrol.caches import FileCache
from bokeh.io import curdoc, show, output_notebook
from bokeh.layouts import column, row, layout
from bokeh.models import ColumnDataSource, CustomJS, Slider, TextInput, DatePicker, PasswordInput, NumericInput, Select, MultiSelect, Button, DataTable, DateFormatter, TableColumn, PreText, Div, TabPanel, Tabs, FileInput, Styles, Range1d
from bokeh.plotting import figure
from datetime import date
from random import randint
import random, time
import urllib.request
from urllib.request import urlopen
import webbrowser
import asyncio
import nest_asyncio
import ctypes
import tkinter
import tkinter as tk
from tkinter import messagebox
from decimal import Decimal

# %%
output_notebook()

# %%
api_key = PasswordInput(title="API Key", placeholder="enter your api key...", width=370)
initial_equity = NumericInput(title="Initial Equity", value=1000000, low=1000000, high=100000000, width=180)
spread_slippage = NumericInput(title="Slippage", value=0.001, low=0.001, high=0.05, mode="float", width=180)
commision = NumericInput(title="Commision", value=0.001, low=0.001, high=0.05, mode="float", width=180)
interest = NumericInput(title="Interest Rate", value=0.001, low=0.001, high=0.05, mode="float", width=180)
riskfree = NumericInput(title="Risk Free Rate", value=0.001, low=0.001, high=0.05, mode="float", width=180)
margin_req = NumericInput(title="Margin Requirement", value=0.001, low=0.001, high=0.05, mode="float", width=180)
margin_maint = NumericInput(title="Margin Maintenance", value=0.001, low=0.001, high=0.05, mode="float", width=180)
leverage = NumericInput(title="Leverage", value=0.001, low=0.001, high=0.05, mode="float", width=180)
setting1 = NumericInput(title="Minimum Data", value=0.001, low=0.001, high=0.05, mode="float", width=180)
setting2 = NumericInput(title="Maximum Data", value=0.001, low=0.001, high=0.05, mode="float", width=180)
setting3 = NumericInput(title="Folder File To Save Report", value=0.001, low=0.001, high=0.05, mode="float", width=180)
setting4 = NumericInput(title="Setting", value=0.001, low=0.001, high=0.05, mode="float", width=180)
data_source = Select(title="Select Data Provider:", value="EOD Historical Data", options=["EOD Historical Data", "Tiingo", "Alpha Vantage", "Twelve Data"], width=180)
exchange = Select(title="Select Exchange:", value="Nasdaq", options=["Nasdaq", "NYSE", "LSE", "Dow"], width=180)
OPTIONS = [("1", "foo0000000000000000000000000000000000000000000000001"), ("2", "bar1"), ("3", "baz1"), ("4", "quux1"),("5", "foo2"), ("6", "bar2"), ("7", "baz2"), ("8", "quux2"),("9", "foo3"), ("10", "bar3"), ("11", "baz3"), ("12", "quux3"),("13", "foo4"), ("14", "bar4"), ("15", "baz4"), ("16", "quux4"),("17", "foo5"), ("18", "bar5"), ("19", "baz5"), ("20", "quux5")]
# option_value_random = [randint(1, 20) for i in range(5)]
# option_value_random_str = map(str, option_value_random)
portfolio = MultiSelect(title="Select Stock:", value=list(map(str, random.sample(range(1, 20), 5))), options= OPTIONS, height=130, width=245)
create_testdata = Button(label="Create Test Data", button_type="success", width=370)
create_apikey = Button(label="Create ApiKey", button_type="default")
run_test = Button(label="Run Test", button_type="primary", width=370)
portfolio_no = Select(title="Select Portfolio:", value="-", options=["-","001", "002", "003", "004"], width=370)
progress1 = NumericInput(value=0.0, low=0.0, high=10000.0, mode="float")
openingithub = Button(label="Test Source Code", button_type="default")
openincolab = Button(label="Test In Colab", button_type="default")
openinkaggle = Button(label="Test In Kaggle", button_type="default")
adddata = Button(label="Add Data", button_type="default")
random_select = Button(label="Random Select", button_type="success", height=115, width=120, margin=(22,0,0,0))

template=("""
        <table style="width: 940px; font-size: 11px; border: 1px solid black">
            <tbody>
                <tr>
                    <td>
                        <table style="width: 344px; border: 1px solid black;">
                            <tbody>
                                <tr>
                                    <td colspan="6" style="text-align: center; border-bottom: 1px solid black"><b>REQUEST - DATA INPUT<b></td>
                                </tr>
                                <tr>
                                    <td colspan="3">Data Sequence No</td>
                                    <td colspan="3">{sequence}</td>
                                </tr>
                                <tr>
                                    <td colspan="3" style="border-bottom: 1px solid black">Equity Balance</td>
                                    <td colspan="3" style="border-bottom: 1px solid black">{equity}</td>
                                </tr>
                                <tr>
                                    <td style='width: 25px; text-align: center; border-bottom: 1px solid black; border-right: 1px solid black'>Stock#</td><td style='width: 60px; text-align: center; border-bottom: 1px solid black; border-right: 1px solid black'>Stock<br>Price</td><td style='width: 87px; text-align: center; border-bottom: 1px solid black; border-right: 1px solid black'>Position<br>Size</td>
                                    <td style='width: 25px; text-align: center; border-bottom: 1px solid black; border-right: 1px solid black'>Stock#</td><td style='width: 60px; text-align: center; border-bottom: 1px solid black; border-right: 1px solid black'>Stock<br>Price</td><td style='width: 87px; text-align: center; border-bottom: 1px solid black'>Position<br>Size</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value1}</td><td style='color: {value211}; text-align: right; border-right: 1px solid black'>{value2}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value3}</td><td style='color: {value411}; text-align: right'>{value4}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value5}</td><td style='color: {value611}; text-align: right; border-right: 1px solid black'>{value6}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value7}</td><td style='color: {value811}; text-align: right;'>{value8}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value9}</td><td style='color: {value1011}; text-align: right; border-right: 1px solid black'>{value10}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value11}</td><td style='color: {value1211}; text-align: right;'>{value12}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value13}</td><td style='color: {value1411}; text-align: right; border-right: 1px solid black'>{value14}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value15}</td><td style='color: {value1611}; text-align: right;'>{value16}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value17}</td><td style='color: {value1811}; text-align: right; border-right: 1px solid black'>{value18}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value19}</td><td style='color: {value2011}; text-align: right;'>{value20}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value21}</td><td style='color: {value2211}; text-align: right; border-right: 1px solid black'>{value22}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value23}</td><td style='color: {value2411}; text-align: right;'>{value24}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value25}</td><td style='color: {value2611}; text-align: right; border-right: 1px solid black'>{value26}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value27}</td><td style='color: {value2811}; text-align: right;'>{value28}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value29}</td><td style='color: {value3011}; text-align: right; border-right: 1px solid black'>{value30}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value31}</td><td style='color: {value3211}; text-align: right;'>{value32}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value33}</td><td style='color: {value3411}; text-align: right; border-right: 1px solid black'>{value34}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value35}</td><td style='color: {value3611}; text-align: right;'>{value36}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value37}</td><td style='color: {value3811}; text-align: right; border-right: 1px solid black'>{value38}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value39}</td><td style='color: {value4011}; text-align: right;'>{value40}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value41}</td><td style='color: {value4211}; text-align: right; border-right: 1px solid black'>{value42}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value43}</td><td style='color: {value4411}; text-align: right;'>{value44}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value45}</td><td style='color: {value4611}; text-align: right; border-right: 1px solid black'>{value46}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value47}</td><td style='color: {value4811}; text-align: right;'>{value48}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value49}</td><td style='color: {value5011}; text-align: right; border-right: 1px solid black'>{value50}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value51}</td><td style='color: {value5211}; text-align: right;'>{value52}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value53}</td><td style='color: {value5411}; text-align: right; border-right: 1px solid black'>{value54}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value55}</td><td style='color: {value5611}; text-align: right;'>{value56}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value57}</td><td style='color: {value5811}; text-align: right; border-right: 1px solid black'>{value58}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value59}</td><td style='color: {value6011}; text-align: right;'>{value60}</td>
                                </tr>
                            </tbody>
                        </table>
                    </td>
                    <td>
                        <div style="width: 252px">
                            <h4 style="text-align: center">REALTIME QUANTXI SIGNAL PROCESSING</h4>
                            <h4 style="text-align: center">Quantxi AI Engine Version : QUANTXI 1.1.5</h4>
                            <h4 style="text-align: center">API End Point = api.xxxx.com</h4>
                            <h4 style="text-align: center">X-User ID = Heri Demo Test</h4>
                            <div class="row" style="text-align: center">
                                <img src="https://raw.githubusercontent.com/guangyoung/test2/main/arrow.png" width="40" height="50" style="margin: 40px 0;">
                                <img src={filee} width="130">
                                <img src="https://raw.githubusercontent.com/guangyoung/test2/main/arrow.png" width="40" height="50" style="margin: 40px 0;">
                            </div>
                            <h4 style="text-align: center">Total Request : {value5}</h4>
                            <h4 style="text-align: center">For Details of API Doc, click Here</h4>
                        </div>
                    </td>
                    <td>
                        <table style="width: 344px; border: 1px solid black">
                            <tbody>
                                <tr>
                                    <td colspan="6" style="text-align: center; border-bottom: 1px solid black"><b>RESPONSE - SIGNAL OUTPUT<b></td>
                                </tr>
                                <tr>
                                    <td colspan="3">Data Sequence No</td>
                                    <td colspan="3">{sequence}</td>
                                </tr>
                                <tr>
                                    <td colspan="3" style="border-bottom: 1px solid black">Equity Balance</td>
                                    <td colspan="3" style="border-bottom: 1px solid black">{equity}</td>
                                </tr>
                                <tr>
                                    <td style='width: 25px; text-align: center; border-bottom: 1px solid black; border-right: 1px solid black'>Stock#</td><td style='width: 60px; text-align: center; border-bottom: 1px solid black; border-right: 1px solid black'>Stock<br>Price</td><td style='width: 87px; text-align: center; border-bottom: 1px solid black; border-right: 1px solid black'>Position<br>Size</td>
                                    <td style='width: 25px; text-align: center; border-bottom: 1px solid black; border-right: 1px solid black'>Stock#</td><td style='width: 60px; text-align: center; border-bottom: 1px solid black; border-right: 1px solid black'>Stock<br>Price</td><td style='width: 87px; text-align: center; border-bottom: 1px solid black'>Position<br>Size</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value1}</td><td style='color: {value211}; text-align: right; border-right: 1px solid black'>{value2}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value3}</td><td style='color: {value411}; text-align: right'>{value4}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value5}</td><td style='color: {value611}; text-align: right; border-right: 1px solid black'>{value6}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value7}</td><td style='color: {value811}; text-align: right;'>{value8}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value9}</td><td style='color: {value1011}; text-align: right; border-right: 1px solid black'>{value10}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value11}</td><td style='color: {value1211}; text-align: right;'>{value12}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value13}</td><td style='color: {value1411}; text-align: right; border-right: 1px solid black'>{value14}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value15}</td><td style='color: {value1611}; text-align: right;'>{value16}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value17}</td><td style='color: {value1811}; text-align: right; border-right: 1px solid black'>{value18}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value19}</td><td style='color: {value2011}; text-align: right;'>{value20}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value21}</td><td style='color: {value2211}; text-align: right; border-right: 1px solid black'>{value22}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value23}</td><td style='color: {value2411}; text-align: right;'>{value24}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value25}</td><td style='color: {value2611}; text-align: right; border-right: 1px solid black'>{value26}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value27}</td><td style='color: {value2811}; text-align: right;'>{value28}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value29}</td><td style='color: {value3011}; text-align: right; border-right: 1px solid black'>{value30}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value31}</td><td style='color: {value3211}; text-align: right;'>{value32}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value33}</td><td style='color: {value3411}; text-align: right; border-right: 1px solid black'>{value34}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value35}</td><td style='color: {value3611}; text-align: right;'>{value36}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value37}</td><td style='color: {value3811}; text-align: right; border-right: 1px solid black'>{value38}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value39}</td><td style='color: {value4011}; text-align: right;'>{value40}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value41}</td><td style='color: {value4211}; text-align: right; border-right: 1px solid black'>{value42}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value43}</td><td style='color: {value4411}; text-align: right;'>{value44}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value45}</td><td style='color: {value4611}; text-align: right; border-right: 1px solid black'>{value46}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value47}</td><td style='color: {value4811}; text-align: right;'>{value48}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value49}</td><td style='color: {value5011}; text-align: right; border-right: 1px solid black'>{value50}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value51}</td><td style='color: {value5211}; text-align: right;'>{value52}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value53}</td><td style='color: {value5411}; text-align: right; border-right: 1px solid black'>{value54}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value55}</td><td style='color: {value5611}; text-align: right;'>{value56}</td>
                                </tr>
                                <tr>
                                    <td>Stock01</td><td style='text-align: right'>{value57}</td><td style='color: {value5811}; text-align: right; border-right: 1px solid black'>{value58}</td>
                                    <td>Stock03</td><td style='text-align: right'>{value59}</td><td style='color: {value6011}; text-align: right;'>{value60}</td>
                                </tr>
                            </tbody>
                        </table>
                    </td>
                </tr>
            </tbody>
        </table>
      """)
template2 = ("""
        <table style="width: 270px; font-size: 11px; border: 1px solid black">
            <tbody>
                <tr>
                    <td colspan="3" style="text-align: center; border-bottom: 1px solid black"><b>PERFORMANCE COMPARISON</b></td>
                </tr>
                <tr>
                    <td style="text-align: center"><u>QUANTZENIUS</u></td>
                    <td style="text-align: center"><u>VS</u></td>
                    <td style="text-align: center"><u>BUY & HOLD</u></td>
                </tr>
                <tr>
                    <td style="text-align: center">1000000000</td>
                    <td style="text-align: center">Equity</td>
                    <td style="text-align: center">1000000000</td>
                </tr>
                <tr>
                    <td style="text-align: center">1000000000</td>
                    <td style="text-align: center">Total Return</td>
                    <td style="text-align: center">1000000000</td>
                </tr>
                <tr>
                    <td style="text-align: center">1000000000</td>
                    <td style="text-align: center">CAGR</td>
                    <td style="text-align: center">1000000000</td>
                </tr>
                <tr>
                    <td style="text-align: center">1000000000</td>
                    <td style="text-align: center">Max DD</td>
                    <td style="text-align: center">1000000000</td>
                </tr>
                <tr>
                    <td style="text-align: center">1000000000</td>
                    <td style="text-align: center">MAR Ratio</td>
                    <td style="text-align: center">1000000000</td>
                </tr>
                <tr>
                    <td style="text-align: center">1000000000</td>
                    <td style="text-align: center">Sharpe</td>
                    <td style="text-align: center">1000000000</td>
                </tr>
                <tr>
                    <td style="text-align: center">1000000000</td>
                    <td style="text-align: center">Sortino</td>
                    <td style="text-align: center">1000000000</td>
                </tr>
                <tr>
                    <td style="text-align: center">1000000000</td>
                    <td style="text-align: center">Sharpe</td>
                    <td style="text-align: center">1000000000</td>
                </tr>
                <tr>
                    <td style="text-align: center">1000000000</td>
                    <td style="text-align: center">Sortino</td>
                    <td style="text-align: center">1000000000</td>
                </tr>
            </tbody>
        </table>
        """)
template3 = ("""
        <table style="width: 270px; font-size: 11px; border: 1px solid black">
            <tbody>
                <tr>
                    <td colspan="2" style="text-align: center; border-bottom: 1px solid black"><b>ACCOUNT SUMMARY</b></td>
                </tr>
                <tr>
                    <td style="text-align: left; padding: 2px 0">Cash Balance</td>
                    <td style="text-align: right"></td>
                </tr>
                <tr>
                    <td style="text-align: left; padding: 2px 0">Long Market Value (LMV)</td>
                    <td style="text-align: right"></td>
                </tr>
                <tr>
                    <td style="text-align: left; padding: 2px 0">Equity With Loan Value (ELV)</td>
                    <td style="text-align: right"></td>
                </tr>
                <tr>
                    <td style="text-align: left; padding: 2px 0">Maintenance Margin Req.</td>
                    <td style="text-align: right"></td>
                </tr>
                <tr>
                    <td style="text-align: left; padding: 2px 0">Excess Liquidity</td>
                    <td style="text-align: right"></td>
                </tr>
                <tr>
                    <td style="text-align: left; padding: 2px 0">Margin Requirement</td>
                    <td style="text-align: right"></td>
                </tr>
                <tr>
                    <td style="text-align: left; padding: 2px 0">Excess Equity</td>
                    <td style="text-align: right"></td>
                </tr>
                <tr>
                    <td colspan="2" style="text-align: justify; padding: 5px 0; border-top: 1px solid black">
                    Perhitungan ini menggunakan motode ilmiah & sesuai standar, anda bisa melakukan cek rumus pada hal ini
                    </td>
                </tr>
            </tbody>
        </table>
        """)
div = Div(text="""""", height=405)
temp_reset = template.format(filee="https://raw.githubusercontent.com/guangyoung/test2/main/ai_gif_logo_1_statis.png", sequence = "", equity = "", value1 = "",value2 = "",value211 = "",value3 = "",value4 = "",value411 = "",value5 = "",value6 = "",value611 = "",value7 = "",value8 = "",value811 = "",
                               value9 = "",value10 = "",value1011 = "",value11 = "",value12 = "",value1211 = "",value13 = "",value14 = "",value1411 = "",value15 = "",value16 = "",value1611 = "",
                               value17 = "",value18 = "",value1811 = "",value19 = "",value20 = "",value2011 = "",value21 = "",value22 = "",value2211 = "",value23 = "",value24 = "",value2411 = "",
                               value25 = "",value26 = "",value2611 = "",value27 = "",value28 = "",value2811 = "",value29 = "",value30 = "",value3011 = "",value31 = "",value32 = "",value3211 = "",
                               value33 = "",value34 = "",value3411 = "",value35 = "",value36 = "",value3611 = "",value37 = "",value38 = "",value3811 = "",value39 = "",value40 = "",value4011 = "",
                               value41 = "",value42 = "",value4211 = "",value43 = "",value44 = "",value4411 = "",value45 = "",value46 = "",value4611 = "",value47 = "",value48 = "",value4811 = "",
                               value49 = "",value50 = "",value5011 = "",value51 = "",value52 = "",value5211 = "",value53 = "",value54 = "",value5411 = "",value55 = "",value56 = "",value5611 = "",
                               value57 = "",value58 = "",value5811 = "",value59 = "",value60 = "",value6011 = "")
div.text = temp_reset
div1 = Div(text="""""", width=270)
div1.text = template2
div2 = Div(text="""""", width=265)
div2.text = template3
# show(api_key)
# show(initial_equity)
# show(spread_slippage)
# show(commision)
# show(interest)
# show(data_source)
# show(exchange)
# show(portfolio)
# show(create_testdata)
# input("yakin ?")
# portfolio_no.options.index(portfolio_no.value)
# progress1.value

# %%
# Set up data
# N = 200
# x = np.linspace(0, 4*np.pi, N)
# y = np.sin(x)
# source = ColumnDataSource(data=dict(x=x, y=y))


# Set up plot
# plot = figure(height=285, width=350, title="my sine wave",
#               tools="crosshair,pan,reset,save,wheel_zoom",
#               x_range=[0, 4*np.pi], y_range=[-2.5, 2.5])

# plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)


# Set up widgets
# text = PreText(text="""QUANTZENIUS""", width=100, height=12)
text1 = Div(text="""<img src="https://raw.githubusercontent.com/guangyoung/test2/main/logo_zenius2.png" width="370" height="60">""")
text2 = Div(text="""<img src="https://raw.githubusercontent.com/guangyoung/test2/main/realtime_signal_testing.png" width="370" height="30">""")
# api_key = PasswordInput(title="API Key", placeholder="enter your api key...", width=180)


# date_picker = DatePicker(
#     title="Select date",
#     value="2019-09-20",
#     min_date="2019-08-01",
#     max_date="2019-10-30",
# )

pre = Div(text="""Don't have API Key ? <a href="https://www.kompas.com" target="_blank">Click here for details</a>""", height=15, styles={'font-size':'10pt', 'font-family':'Arial'})

data = dict(
            downloads1=[],
            downloads2=[],
            downloads3=[],
            downloads4=[],
            downloads5=[],
            downloads6=[],
            downloads7=[],
            downloads8=[],
            downloads9=[],
            downloads10=[],
            downloads11=[],
            downloads12=[],
            downloads13=[],
            downloads14=[],
            downloads15=[],
            downloads16=[],
            downloads17=[],
            downloads18=[],
            downloads19=[],
            downloads20=[],
            downloads21=[],
            downloads22=[],
            downloads23=[],
            downloads24=[],
            downloads25=[],
            downloads26=[],
            downloads27=[],
            downloads28=[],
            downloads29=[],
            downloads30=[],
            downloads31=[]
        )
source = ColumnDataSource(data)

columns = [
        TableColumn(field="downloads1", title="1"),
        TableColumn(field="downloads2", title="2"),
        TableColumn(field="downloads3", title="3"),
        TableColumn(field="downloads4", title="4"),
        TableColumn(field="downloads5", title="5"),
        TableColumn(field="downloads6", title="6"),
        TableColumn(field="downloads7", title="7"),
        TableColumn(field="downloads8", title="8"),
        TableColumn(field="downloads9", title="9"),
        TableColumn(field="downloads10", title="10"),
        TableColumn(field="downloads11", title="11"),
        TableColumn(field="downloads12", title="12"),
        TableColumn(field="downloads13", title="13"),
        TableColumn(field="downloads14", title="14"),
        TableColumn(field="downloads15", title="15"),
        TableColumn(field="downloads16", title="16"),
        TableColumn(field="downloads17", title="17"),
        TableColumn(field="downloads18", title="18"),
        TableColumn(field="downloads19", title="19"),
        TableColumn(field="downloads20", title="20"),
        TableColumn(field="downloads21", title="21"),
        TableColumn(field="downloads22", title="22"),
        TableColumn(field="downloads23", title="23"),
        TableColumn(field="downloads24", title="24"),
        TableColumn(field="downloads25", title="25"),
        TableColumn(field="downloads26", title="26"),
        TableColumn(field="downloads27", title="27"),
        TableColumn(field="downloads28", title="28"),
        TableColumn(field="downloads29", title="29"),
        TableColumn(field="downloads30", title="30"),
        TableColumn(field="downloads31", title="31"),
    ]
data_table = DataTable(source=source, columns=columns, width=370, height=200, frozen_columns= 2, sortable= False)

def set_portfolio(attr, old, new):
    # div.text="""LOADING..."""
    ran = (portfolio_no.options.index(portfolio_no.value)) * 100
    ran1 = (portfolio_no.options.index(portfolio_no.value)) * 5000
    data_table.source.data = dict(
            downloads1=[randint(0, ran) for i in range(ran1)],
            downloads2=[randint(0, ran) for i in range(ran1)],
            downloads3=[randint(0, ran) for i in range(ran1)],
            downloads4=[randint(0, ran) for i in range(ran1)],
            downloads5=[randint(0, ran) for i in range(ran1)],
            downloads6=[randint(0, ran) for i in range(ran1)],
            downloads7=[randint(0, ran) for i in range(ran1)],
            downloads8=[randint(0, ran) for i in range(ran1)],
            downloads9=[randint(0, ran) for i in range(ran1)],
            downloads10=[randint(0, ran) for i in range(ran1)],
            downloads11=[randint(0, ran) for i in range(ran1)],
            downloads12=[randint(0, ran) for i in range(ran1)],
            downloads13=[randint(0, ran) for i in range(ran1)],
            downloads14=[randint(0, ran) for i in range(ran1)],
            downloads15=[randint(0, ran) for i in range(ran1)],
            downloads16=[randint(0, ran) for i in range(ran1)],
            downloads17=[randint(0, ran) for i in range(ran1)],
            downloads18=[randint(0, ran) for i in range(ran1)],
            downloads19=[randint(0, ran) for i in range(ran1)],
            downloads20=[randint(0, ran) for i in range(ran1)],
            downloads21=[randint(0, ran) for i in range(ran1)],
            downloads22=[randint(0, ran) for i in range(ran1)],
            downloads23=[randint(0, ran) for i in range(ran1)],
            downloads24=[randint(0, ran) for i in range(ran1)],
            downloads25=[randint(0, ran) for i in range(ran1)],
            downloads26=[randint(0, ran) for i in range(ran1)],
            downloads27=[randint(0, ran) for i in range(ran1)],
            downloads28=[randint(0, ran) for i in range(ran1)],
            downloads29=[randint(0, ran) for i in range(ran1)],
            downloads30=[randint(0, ran) for i in range(ran1)],
            downloads31=[randint(0, ran) for i in range(ran1)]
        )
    # div.text=""""""
# def loading(attr, old, new):
#     div.text="""LOADING..."""
# portfolio_no.on_change("value",loading)
portfolio_no.on_change("value",set_portfolio)
# ticker_data = pdr.get_data_yahoo("SPY", start="2017-01-01", end="2017-04-30")
# ticker_data = pdr.get_data_yahoo('AAPL', start=datetime.datetime(1900, 1, 1), end=datetime.datetime(2022, 1, 1))
data_p1 = {'x_values': [1, 2, 3, 4, 5],
        'y_values': [6, 7, 2, 4, 5]}
source_p1 = ColumnDataSource(dict(x_values=[], y_values=[]))
p1 = figure(width=410, height=195)
# p1.x_range = Range1d(0, 1200)
# p1.y_range = Range1d(0, 1200)
p1.line(x='x_values', y='y_values', source=source_p1, line_width=3, color="navy", alpha=0.5)
tabp1 = TabPanel(child=p1, title="Total Return")

p2 = figure(width=410, height=195)
p2.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], line_width=3, color="navy", alpha=0.5)
tabp2 = TabPanel(child=p2, title="CAGR")

p3 = figure(width=410, height=195)
p3.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], line_width=3, color="navy", alpha=0.5)
tabp3 = TabPanel(child=p3, title="Max DD")

p4 = figure(width=410, height=195)
p4.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], line_width=3, color="navy", alpha=0.5)
tabp4 = TabPanel(child=p4, title="Sharpe")

tab_p = Tabs(tabs=[tabp1, tabp2, tabp3, tabp4])
tab_trade = data_table
tab1 = TabPanel(child=row(data_table), title="Performance Comparison")
tab2 = TabPanel(child=row(tab_p), title="Performance Chart")
tab3 = TabPanel(child=tab_trade, title="Account & Trade Summary")
tab4 = TabPanel(child=tab_trade, title="Test History")

tt = Tabs(tabs=[tab1, tab2, tab3, tab4])

# row11 = row(text1, text2)
# row12 = row(openingithub, openincolab, openinkaggle)
# row13 = row(tt0)
# row1311 = row(api_key, api_key)
# row1312 = row(initial_equity, spread_slippage)
# row1313 = row(commision, interest)
# row1321 = row(data_source, exchange)
# row1322 = row(portfolio)
file_input1 = FileInput(width = 370, title = "You can also upload your cleared portfolio Testdata. Learn more")
data_file = DataTable(width=370, height=150)

tab131 = column(row(api_key, height=50), pre, row(initial_equity, spread_slippage),row(commision, interest), row(riskfree, margin_req), row(margin_maint, leverage))
tab132 = column(row(data_source, exchange), row(portfolio, random_select, height=140), row(create_testdata, height=35), data_table)
tab133 = column(row(file_input1, adddata), data_file)
tab11 = TabPanel(child=tab132, title="------ Data From Provider -----")
tab12 = TabPanel(child=tab133, title="--------- Data From Yours -------")
tt1 = Tabs(tabs=[tab11, tab12],height=225)
tab1112 = column(tab132, row(file_input1, height=40), data_table)
tab01 = TabPanel(child=tab131, title="----------- Test Setting -----------")
tab02 = TabPanel(child=tab132, title="------------- Test Data -------------")
tt0 = Tabs(tabs=[tab01, tab02],height=470)

def reset2():

    # p1_x_data = {"data":[]}
    # p1_y_data = {"data":[]}
    curdoc().add_next_tick_callback(disable)
    # div.text="""<img src="https://raw.githubusercontent.com/guangyoung/test2/main/xp.gif" height="20" alt="div_image">"""
    y=0
    while y < 7000:
        # progress1.value = round(len(portfolio_data["data"]),2)
        # data_table.source.data = dict(
        #         downloads1=[],
        #         downloads2=[],
        #         downloads3=[],
        #         downloads4=[],
        #         downloads5=[],
        #         downloads6=[],
        #         downloads7=[],
        #         downloads8=[],
        #         downloads9=[],
        #         downloads10=[],
        #         downloads11=[],
        #         downloads12=[],
        #         downloads13=[],
        #         downloads14=[],
        #         downloads15=[],
        #         downloads16=[],
        #         downloads17=[],
        #         downloads18=[],
        #         downloads19=[],
        #         downloads20=[],
        #         downloads21=[],
        #         downloads22=[],
        #         downloads23=[],
        #         downloads24=[],
        #         downloads25=[],
        #         downloads26=[],
        #         downloads27=[],
        #         downloads28=[],
        #         downloads29=[],
        #         downloads30=[],
        #         downloads31=[]
        #     )
        # progress()

        curdoc().add_next_tick_callback(progress)
        y=y+1
    # curdoc().add_next_tick_callback(undisable)
    curdoc().add_next_tick_callback(reset)

    # p1_x_data = {"data":[]}
    # p1_y_data = {"data":[]}
def disable():
    global portfolio_data
    global step
    step = 5
    portfolio_data = {"data":[]}
    tab_p.disabled=True
    run_test.disabled=True
    random_select.disabled=True
    create_testdata.disabled=True
    portfolio_data = {"data":[]}
    # source_p1.data = dict(x_values=[], y_values=[])
    new_data =dict(x_values=[1],y_values=[randint(0+(1*1), (100+(1*1)))])
    source_p1.stream(new_data)
# def undisable():
#     tt.disabled=False

# def pretty_float(val):
#     if len(repr(val)) > 9:
#       return "{:.8e}".format(val)
#     else:
#       return "{:,.0f}".format(val)

session = CacheControl(requests.Session())
# session = requests.Session()

apiurl = "https://datausa.io/api/data?drilldowns=Nation&measures=Population"
# x=0.0
gbr = "https://raw.githubusercontent.com/guangyoung/test2/main/ai_gif_logo_1_crop.gif"
def progress():
    global step
    # portfolio_data = {"data":[]}
    # progress1.value = 0
    # x=0.0
    # c=0.0
    response = session.get(apiurl)
    portfolio_data["data"].append(response.json())
    sinyal_color = {"sinyal":[],"color":[]}
    val = 0
    for x in range(30):
        if len(repr(round(len(portfolio_data["data"]),2)+1000000)) > 9:
            val = "{:.8e}".format(round(len(portfolio_data["data"]),2)+1000000)
        else:
            val = "{:,.0f}".format(round(len(portfolio_data["data"]),2)+1000000)

        if (randint(0, 10) % 2) == 0:
            sinyal_color["sinyal"].append("BUY")
            sinyal_color["color"].append('#40ff00')
        else:
            sinyal_color["sinyal"].append("SELL")
            sinyal_color["color"].append('#ff0000')
    div.text = template.format(filee=gbr,
                               sequence = round(len(portfolio_data["data"]),2),
                               equity = val,
                               value1 = val,
                               value2 = sinyal_color["sinyal"][0],
                               value211 = sinyal_color["color"][0],
                               value3 = val,
                               value4 = sinyal_color["sinyal"][1],
                               value411 = sinyal_color["color"][1],
                               value5 = val,
                               value6 = sinyal_color["sinyal"][2],
                               value611 = sinyal_color["color"][2],
                               value7 = val,
                               value8 = sinyal_color["sinyal"][3],
                               value811 = sinyal_color["color"][3],
                               value9 = val,
                               value10 = sinyal_color["sinyal"][4],
                               value1011 = sinyal_color["color"][4],
                               value11 = val,
                               value12 = sinyal_color["sinyal"][5],
                               value1211 = sinyal_color["color"][5],
                               value13 = val,
                               value14 = sinyal_color["sinyal"][6],
                               value1411 = sinyal_color["color"][6],
                               value15 = val,
                               value16 = sinyal_color["sinyal"][7],
                               value1611 = sinyal_color["color"][7],
                               value17 = val,
                               value18 = sinyal_color["sinyal"][8],
                               value1811 = sinyal_color["color"][8],
                               value19 = val,
                               value20 = sinyal_color["sinyal"][9],
                               value2011 = sinyal_color["color"][9],
                               value21 = val,
                               value22 = sinyal_color["sinyal"][10],
                               value2211 = sinyal_color["color"][10],
                               value23 = val,
                               value24 = sinyal_color["sinyal"][11],
                               value2411 = sinyal_color["color"][11],
                               value25 = val,
                               value26 = sinyal_color["sinyal"][12],
                               value2611 = sinyal_color["color"][12],
                               value27 = val,
                               value28 = sinyal_color["sinyal"][13],
                               value2811 = sinyal_color["color"][13],
                               value29 = val,
                               value30 = sinyal_color["sinyal"][14],
                               value3011 = sinyal_color["color"][14],
                               value31 = val,
                               value32 = sinyal_color["sinyal"][15],
                               value3211 = sinyal_color["color"][15],
                               value33 = val,
                               value34 = sinyal_color["sinyal"][16],
                               value3411 = sinyal_color["color"][16],
                               value35 = val,
                               value36 = sinyal_color["sinyal"][17],
                               value3611 = sinyal_color["color"][17],
                               value37 = val,
                               value38 = sinyal_color["sinyal"][18],
                               value3811 = sinyal_color["color"][18],
                               value39 = val,
                               value40 = sinyal_color["sinyal"][19],
                               value4011 = sinyal_color["color"][19],
                               value41 = val,
                               value42 = sinyal_color["sinyal"][20],
                               value4211 = sinyal_color["color"][20],
                               value43 = val,
                               value44 = sinyal_color["sinyal"][21],
                               value4411 = sinyal_color["color"][21],
                               value45 = val,
                               value46 = sinyal_color["sinyal"][22],
                               value4611 = sinyal_color["color"][22],
                               value47 = val,
                               value48 = sinyal_color["sinyal"][23],
                               value4811 = sinyal_color["color"][23],
                               value49 = val,
                               value50 = sinyal_color["sinyal"][24],
                               value5011 = sinyal_color["color"][24],
                               value51 = val,
                               value52 = sinyal_color["sinyal"][25],
                               value5211 = sinyal_color["color"][25],
                               value53 = val,
                               value54 = sinyal_color["sinyal"][26],
                               value5411 = sinyal_color["color"][26],
                               value55 = val,
                               value56 = sinyal_color["sinyal"][27],
                               value5611 = sinyal_color["color"][27],
                               value57 = val,
                               value58 = sinyal_color["sinyal"][28],
                               value5811 = sinyal_color["color"][28],
                               value59 = val,
                               value60 = sinyal_color["sinyal"][29],
                               value6011 = sinyal_color["color"][29])
    # p1_x_data["data"].append(len(portfolio_data["data"]))
    # p1_y_data["data"].append(randint(0+(len(portfolio_data["data"])*1), (100+(len(portfolio_data["data"])*1))))
    new_data =dict(x_values=[len(portfolio_data["data"])],y_values=[randint(0+(len(portfolio_data["data"])*1), (100+(len(portfolio_data["data"])*1)))])
    if (len(portfolio_data["data"])-step)==0:
        source_p1.stream(new_data)
        step = step+5

    # progress1.value = round(len(portfolio_data["data"]),2)
    # div1.text = template1.format(respon = response.json())
        # print(response)
        # a = 100.0
        # b = 1548425154.2531
        # c = c+(a*b)

    # x = x+1
    # ctypes.windll.user32.MessageBoxExW(0, 'FINISH', 'Selesai', 0x00001000)
    # progress1.value = 0
    # time.sleep(2)
    # reset2()
    # div.text=""""""
    # ran = (portfolio_no.options.index(portfolio_no.value)) * 100
    # ran1 = (portfolio_no.options.index(portfolio_no.value)) * 5000
    # data_table.source.data = dict(
    #         downloads1=[randint(0, ran) for i in range(ran1)],
    #         downloads2=[randint(0, ran) for i in range(ran1)],
    #         downloads3=[randint(0, ran) for i in range(ran1)],
    #         downloads4=[randint(0, ran) for i in range(ran1)],
    #         downloads5=[randint(0, ran) for i in range(ran1)],
    #         downloads6=[randint(0, ran) for i in range(ran1)],
    #         downloads7=[randint(0, ran) for i in range(ran1)],
    #         downloads8=[randint(0, ran) for i in range(ran1)],
    #         downloads9=[randint(0, ran) for i in range(ran1)],
    #         downloads10=[randint(0, ran) for i in range(ran1)],
    #         downloads11=[randint(0, ran) for i in range(ran1)],
    #         downloads12=[randint(0, ran) for i in range(ran1)],
    #         downloads13=[randint(0, ran) for i in range(ran1)],
    #         downloads14=[randint(0, ran) for i in range(ran1)],
    #         downloads15=[randint(0, ran) for i in range(ran1)],
    #         downloads16=[randint(0, ran) for i in range(ran1)],
    #         downloads17=[randint(0, ran) for i in range(ran1)],
    #         downloads18=[randint(0, ran) for i in range(ran1)],
    #         downloads19=[randint(0, ran) for i in range(ran1)],
    #         downloads20=[randint(0, ran) for i in range(ran1)],
    #         downloads21=[randint(0, ran) for i in range(ran1)],
    #         downloads22=[randint(0, ran) for i in range(ran1)],
    #         downloads23=[randint(0, ran) for i in range(ran1)],
    #         downloads24=[randint(0, ran) for i in range(ran1)],
    #         downloads25=[randint(0, ran) for i in range(ran1)],
    #         downloads26=[randint(0, ran) for i in range(ran1)],
    #         downloads27=[randint(0, ran) for i in range(ran1)],
    #         downloads28=[randint(0, ran) for i in range(ran1)],
    #         downloads29=[randint(0, ran) for i in range(ran1)],
    #         downloads30=[randint(0, ran) for i in range(ran1)],
    #         downloads31=[randint(0, ran) for i in range(ran1)]
    #     )
    # div.text=""""""

def reset():
    div.text = temp_reset
    tab_p.disabled=False
    run_test.disabled=False
    random_select.disabled=False
    create_testdata.disabled=False
    new_data =dict(x_values=[len(portfolio_data["data"])],y_values=[randint(0+(len(portfolio_data["data"])*1), (100+(len(portfolio_data["data"])*1)))])
    source_p1.stream(new_data)
# button_classify = Button(label="Create Pop-up alert")
# callback = CustomJS(args={}, code='alert("hello!");')
# button_classify.js_on_click(callback)



inputs1 = column(row(text2, height=30), row(text1, height=65), row(openingithub, openincolab, openinkaggle, height=45), tt0, run_test, background="#9494b8", width=380, height=650)
# inputs2 = column(text2, openincolab, data_source, exchange, portfolio, create_testdata, portfolio_no,background="deepskyblue", width=190)
# inputs3 = column(data_table, create_apikey, background="deepskyblue", width=380)
inputs4 = column(row(div2, div1, tab_p, background="#b3b3cc"), row(div, background="#a3a3c2"), width=965, height=650)
# inputs5 = column(div)
# Set up callbacks
def update_comm():
    commision.value = 0.05
    portfolio.value=list(map(str, random.sample(range(1, 20), 5)))

run_test.on_click(reset2)
# url= 'https://www.javatpoint.com/python-tutorial'
# print(len(portfolio_data["data"]))
def open_url():
    # progress1.value = 0
    webbrowser.open_new_tab('https://www.javatpoint.com/python-tutorial')
create_apikey.on_click(open_url)

def update_spread(attr, old, new):
    spread_slippage.value = 0.05*commision.value

commision.on_change('value', update_spread)
commision.js_on_change('value', CustomJS(args={}, code='alert("hello!");'))

curdoc().theme = 'light_minimal'
# curdoc().add_root(row(text1, text2, width=1345, background="darkslategray"))
curdoc().add_root(row(inputs1, inputs4))
# curdoc().add_root(row(inputs3, tt, width=1345))
curdoc().title = "Sliders"
print("end")
# Out:
# end
