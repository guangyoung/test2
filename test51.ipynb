# %% [markdown]
# <a href="https://colab.research.google.com/github/guangyoung/test2/blob/main/test51.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import requests
from urllib3 import PoolManager
from cachecontrol import CacheControl
# from cachecontrol.caches import FileCache
from bokeh.io import curdoc, show, output_notebook
from bokeh.layouts import column, row, layout
from bokeh.models import ColumnDataSource, CustomJS, Slider, TextInput, DatePicker, PasswordInput, NumericInput, Select, MultiSelect, Button, DataTable, DateFormatter, TableColumn, PreText, Div, TabPanel, Tabs
from bokeh.plotting import figure
from datetime import date
from random import randint
import random, time
import urllib.request
from urllib.request import urlopen
import webbrowser
import asyncio
import nest_asyncio
import ctypes
import tkinter
import tkinter as tk
from tkinter import messagebox
from decimal import Decimal

# %%
output_notebook()

# %%
api_key = PasswordInput(title="API Key", placeholder="enter your api key...", sizing_mode="inherit")
initial_equity = NumericInput(title="Initial Equity", value=1000000, low=1000000, high=100000000, sizing_mode="inherit")
spread_slippage = NumericInput(title="Spread+Slippage", value=0.001, low=0.001, high=0.05, mode="float", sizing_mode="inherit")
commision = NumericInput(title="Commision", value=0.001, low=0.001, high=0.05, mode="float", sizing_mode="inherit")
interest = NumericInput(title="Interest", value=0.001, low=0.001, high=0.05, mode="float", sizing_mode="inherit")
data_source = Select(title="Select Data Source:", value="EOD Historical Data", options=["EOD Historical Data", "Tiingo", "Alpha Vantage", "Twelve Data"])
exchange = Select(title="Select Exchange:", value="Nasdaq", options=["Nasdaq", "NYSE", "LSE", "Dow"])
OPTIONS = [("1", "foo1"), ("2", "bar1"), ("3", "baz1"), ("4", "quux1"),("5", "foo2"), ("6", "bar2"), ("7", "baz2"), ("8", "quux2"),("9", "foo3"), ("10", "bar3"), ("11", "baz3"), ("12", "quux3"),("13", "foo4"), ("14", "bar4"), ("15", "baz4"), ("16", "quux4"),("17", "foo5"), ("18", "bar5"), ("19", "baz5"), ("20", "quux5")]
# option_value_random = [randint(1, 20) for i in range(5)]
# option_value_random_str = map(str, option_value_random)
portfolio = MultiSelect(title="Select Stock:", value=list(map(str, random.sample(range(1, 20), 5))), options= OPTIONS, height=70)
create_testdata = Button(label="Create Testdata", button_type="success")
create_apikey = Button(label="Create Apikey", button_type="success", width=370)
portfolio_no = Select(title="Select Portfolio:", value="-", options=["-","001", "002", "003", "004"])
progress1 = NumericInput(value=0.0, low=0.0, high=10000.0, mode="float")

template=("""
        <div class='content'>
            <div class="table-report" style="font-size: 11px">
                <table style="width: 940px; border: 1px solid black">
                    <tbody>
                        <tr>
                            <td>
                                <div class="table-report">
                                    <table style="width: 344px; border: 1px solid black;">
                                        <tbody>
                                            <tr>
                                                <td colspan="6" style="text-align: center">DATA INPUT</td>
                                            </tr>
                                            <tr>
                                                <td colspan="3">Data Sequence No :</td>
                                                <td colspan="3">123456</td>
                                            </tr>
                                            <tr>
                                                <td colspan="3" style="border-bottom: 1px solid black">Equity Balance</td>
                                                <td colspan="3" style="border-bottom: 1px solid black">100.000.000,00</td>
                                            </tr>
                                            <tr>
                                                <td style='text-align: center'>Stock#</td><td style='text-align: center'>Price</td><td style='text-align: center'>Position Size</td>
                                                <td style='text-align: center'>Stock#</td><td style='text-align: center'>Price</td><td style='text-align: center'>Position Size</td>
                                            </tr>
                                            <tr>
                                                <td style='width: 20px'>barang1</td><td style='width: 122px; text-align: right'>{value1}</td><td style='width: 30px; color: {value211}; text-align: right'>{value2}</td>
                                                <td  style='width: 20px'>barang3</td><td style='width: 122px; text-align: right'>{value3}</td><td style='width: 30px; color: {value411}; text-align: right'>{value4}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value5}</td><td style='color: {value611};'>{value6}</td>
                                                <td>barang3</td><td>{value7}</td><td style='color: {value811};'>{value8}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value9}</td><td style='color: {value1011};'>{value10}</td>
                                                <td>barang3</td><td>{value11}</td><td style='color: {value1211};'>{value12}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value13}</td><td style='color: {value1411};'>{value14}</td>
                                                <td>barang3</td><td>{value15}</td><td style='color: {value1611};'>{value16}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value17}</td><td style='color: {value1811};'>{value18}</td>
                                                <td>barang3</td><td>{value19}</td><td style='color: {value2011};'>{value20}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value21}</td><td style='color: {value2211};'>{value22}</td>
                                                <td>barang3</td><td>{value23}</td><td style='color: {value2411};'>{value24}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value25}</td><td style='color: {value2611};'>{value26}</td>
                                                <td>barang3</td><td>{value27}</td><td style='color: {value2811};'>{value28}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value29}</td><td style='color: {value3011};'>{value30}</td>
                                                <td>barang3</td><td>{value31}</td><td style='color: {value3211};'>{value32}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value33}</td><td style='color: {value3411};'>{value34}</td>
                                                <td>barang3</td><td>{value35}</td><td style='color: {value3611};'>{value36}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value37}</td><td style='color: {value3811};'>{value38}</td>
                                                <td>barang3</td><td>{value39}</td><td style='color: {value4011};'>{value40}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value41}</td><td style='color: {value4211};'>{value42}</td>
                                                <td>barang3</td><td>{value43}</td><td style='color: {value4411};'>{value44}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value45}</td><td style='color: {value4611};'>{value46}</td>
                                                <td>barang3</td><td>{value47}</td><td style='color: {value4811};'>{value48}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value49}</td><td style='color: {value5011};'>{value50}</td>
                                                <td>barang3</td><td>{value51}</td><td style='color: {value5211};'>{value52}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value53}</td><td style='color: {value5411};'>{value54}</td>
                                                <td>barang3</td><td>{value55}</td><td style='color: {value5611};'>{value56}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value57}</td><td style='color: {value5811};'>{value58}</td>
                                                <td>barang3</td><td>{value59}</td><td style='color: {value6011};'>{value60}</td>
                                            </tr>
                                        </tbody>
                                    </table>
                                </div>
                            </td>
                            <td>
                                <div style="width: 252px">
                                    <h4 style="text-align: center">Quantxi AI Engine Version : QUANTXI 1.1.5</h4>
                                    <h4 style="text-align: center">API End Point = api.xxxx.com</h4>
                                    <h4 style="text-align: center">X-User ID = Heri Demo Test</h4>
                                    <div class="row" style="text-align: center">
                                        <img src="https://raw.githubusercontent.com/guangyoung/test2/main/arrow.png" width="40" height="50" style="margin: 40px 0;">
                                        <img src={filee} width="130">
                                        <img src="https://raw.githubusercontent.com/guangyoung/test2/main/arrow.png" width="40" height="50" style="margin: 40px 0;">
                                    </div>
                                    <h4 style="text-align: center">Total Request : {value5}</h4>
                                    <h4 style="text-align: center">For Details of API Doc, click Here</h4>
                                </div>
                            </td>
                            <td>
                                <div class="table-report">
                                    <table style="width: 344px; border: 1px solid black; table-layout: fixed;">
                                        <tbody>
                                            <tr>
                                                <td colspan="6" style="text-align: center">SIGNAL OUTPUT</td>
                                            </tr>
                                            <tr>
                                                <td colspan="3">Data Sequence No :</td>
                                                <td colspan="3">123456</td>
                                            </tr>
                                            <tr>
                                                <td colspan="3" style="border-bottom: 1px solid black">Equity Balance</td>
                                                <td colspan="3" style="border-bottom: 1px solid black">100.000.000,00</td>
                                            </tr>
                                            <tr>
                                                <td style='text-align: center'>Stock#</td><td style='text-align: center'>Signal Position</td><td style='text-align: center'>Signal Size</td>
                                                <td style='text-align: center'>Stock#</td><td style='text-align: center'>Signal Position</td><td style='text-align: center'>Signal Size</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value1}</td><td style='color: {value211};text-align: right'>{value2}</td>
                                                <td>barang3</td><td>{value3}</td><td style='color: {value411};'>{value4}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value5}</td><td style='color: {value611};'>{value6}</td>
                                                <td>barang3</td><td>{value7}</td><td style='color: {value811};'>{value8}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value9}</td><td style='color: {value1011};'>{value10}</td>
                                                <td>barang3</td><td>{value11}</td><td style='color: {value1211};'>{value12}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value13}</td><td style='color: {value1411};'>{value14}</td>
                                                <td>barang3</td><td>{value15}</td><td style='color: {value1611};'>{value16}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value17}</td><td style='color: {value1811};'>{value18}</td>
                                                <td>barang3</td><td>{value19}</td><td style='color: {value2011};'>{value20}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value21}</td><td style='color: {value2211};'>{value22}</td>
                                                <td>barang3</td><td>{value23}</td><td style='color: {value2411};'>{value24}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value25}</td><td style='color: {value2611};'>{value26}</td>
                                                <td>barang3</td><td>{value27}</td><td style='color: {value2811};'>{value28}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value29}</td><td style='color: {value3011};'>{value30}</td>
                                                <td>barang3</td><td>{value31}</td><td style='color: {value3211};'>{value32}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value33}</td><td style='color: {value3411};'>{value34}</td>
                                                <td>barang3</td><td>{value35}</td><td style='color: {value3611};'>{value36}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value37}</td><td style='color: {value3811};'>{value38}</td>
                                                <td>barang3</td><td>{value39}</td><td style='color: {value4011};'>{value40}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value41}</td><td style='color: {value4211};'>{value42}</td>
                                                <td>barang3</td><td>{value43}</td><td style='color: {value4411};'>{value44}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value45}</td><td style='color: {value4611};'>{value46}</td>
                                                <td>barang3</td><td>{value47}</td><td style='color: {value4811};'>{value48}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value49}</td><td style='color: {value5011};'>{value50}</td>
                                                <td>barang3</td><td>{value51}</td><td style='color: {value5211};'>{value52}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value53}</td><td style='color: {value5411};'>{value54}</td>
                                                <td>barang3</td><td>{value55}</td><td style='color: {value5611};'>{value56}</td>
                                            </tr>
                                            <tr>
                                                <td>barang1</td><td>{value57}</td><td style='color: {value5811};'>{value58}</td>
                                                <td>barang3</td><td>{value59}</td><td style='color: {value6011};'>{value60}</td>
                                            </tr>
                                        </tbody>
                                    </table>
                                </div>
                            </td>
                        </tr>
                    </tbody>
                </table>
            </div>
        </div>
      """)
template1=("""
        <div class='content'>
            <div class="table-report" style="font-size: 11px">
                <table style="border: 1px solid black">
                </table>
                    <tbody>
                        <tr>
                            <td colspan="3">{respon}</td>
                        </tr>
                    </tbody>
                </table>
            </div>
        </div>
        """)
div = Div(text="""""",width=500, height=400)
temp_reset = template.format(filee="https://raw.githubusercontent.com/guangyoung/test2/main/ai_gif_logo_1_statis.png", value1 = "",value2 = "",value211 = "",value3 = "",value4 = "",value411 = "",value5 = "",value6 = "",value611 = "",value7 = "",value8 = "",value811 = "",
                               value9 = "",value10 = "",value1011 = "",value11 = "",value12 = "",value1211 = "",value13 = "",value14 = "",value1411 = "",value15 = "",value16 = "",value1611 = "",
                               value17 = "",value18 = "",value1811 = "",value19 = "",value20 = "",value2011 = "",value21 = "",value22 = "",value2211 = "",value23 = "",value24 = "",value2411 = "",
                               value25 = "",value26 = "",value2611 = "",value27 = "",value28 = "",value2811 = "",value29 = "",value30 = "",value3011 = "",value31 = "",value32 = "",value3211 = "",
                               value33 = "",value34 = "",value3411 = "",value35 = "",value36 = "",value3611 = "",value37 = "",value38 = "",value3811 = "",value39 = "",value40 = "",value4011 = "",
                               value41 = "",value42 = "",value4211 = "",value43 = "",value44 = "",value4411 = "",value45 = "",value46 = "",value4611 = "",value47 = "",value48 = "",value4811 = "",
                               value49 = "",value50 = "",value5011 = "",value51 = "",value52 = "",value5211 = "",value53 = "",value54 = "",value5411 = "",value55 = "",value56 = "",value5611 = "",
                               value57 = "",value58 = "",value5811 = "",value59 = "",value60 = "",value6011 = "")
div.text = temp_reset
div1 = Div(text="""""",width=500)
temp1_reset = template1.format(respon = "")
show(api_key)
show(initial_equity)
show(spread_slippage)
show(commision)
show(interest)
show(data_source)
show(exchange)
show(portfolio)
# show(create_testdata)
# input("yakin ?")
# portfolio_no.options.index(portfolio_no.value)
progress1.value
# Out:
#   <div id="b87eaced-5f04-4590-bed4-c3b0d8eaa7d9" data-root-id="p4658" style="display: contents;"></div>
#   <div id="c7d48f2d-0925-4887-ac7d-3ee26f70e5c8" data-root-id="p4659" style="display: contents;"></div>
#   <div id="ef22cd4b-2cc1-42b6-95a3-0a24f76630f6" data-root-id="p4660" style="display: contents;"></div>
#   <div id="ea02f492-4508-4f97-aca9-8c43bf199a2a" data-root-id="p4661" style="display: contents;"></div>
#   <div id="d1c52c5a-d301-4085-9198-243d46818951" data-root-id="p4662" style="display: contents;"></div>
#   <div id="fba7114d-2a33-4f9e-9276-be482d00201f" data-root-id="p4663" style="display: contents;"></div>
#   <div id="e54e006d-6ac6-475b-bfe8-a275247d0b3b" data-root-id="p4664" style="display: contents;"></div>
#   <div id="d9603892-46c4-4226-a66f-5ca906459f56" data-root-id="p4665" style="display: contents;"></div>
# 0.0

# %%
# Set up data
# N = 200
# x = np.linspace(0, 4*np.pi, N)
# y = np.sin(x)
# source = ColumnDataSource(data=dict(x=x, y=y))


# Set up plot
# plot = figure(height=285, width=350, title="my sine wave",
#               tools="crosshair,pan,reset,save,wheel_zoom",
#               x_range=[0, 4*np.pi], y_range=[-2.5, 2.5])

# plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)


# Set up widgets
# text = PreText(text="""QUANTZENIUS""", width=100, height=12)
text1 = Div(text="""<img src="https://raw.githubusercontent.com/guangyoung/test2/main/logo_quantxi1.png" width="180" height="30" alt="div_image">""")
text2 = Div(text="""<img src="https://raw.githubusercontent.com/guangyoung/test2/main/systemtesting.png" width="180" height="30" alt="div_image">""")
# api_key = PasswordInput(title="API Key", placeholder="enter your api key...", width=180)


# date_picker = DatePicker(
#     title="Select date",
#     value="2019-09-20",
#     min_date="2019-08-01",
#     max_date="2019-10-30",
# )

pre = PreText(text="""TESTDATA""", width=100, height=12)

data = dict(
            downloads1=[],
            downloads2=[],
            downloads3=[],
            downloads4=[],
            downloads5=[],
            downloads6=[],
            downloads7=[],
            downloads8=[],
            downloads9=[],
            downloads10=[],
            downloads11=[],
            downloads12=[],
            downloads13=[],
            downloads14=[],
            downloads15=[],
            downloads16=[],
            downloads17=[],
            downloads18=[],
            downloads19=[],
            downloads20=[],
            downloads21=[],
            downloads22=[],
            downloads23=[],
            downloads24=[],
            downloads25=[],
            downloads26=[],
            downloads27=[],
            downloads28=[],
            downloads29=[],
            downloads30=[],
            downloads31=[]
        )
source = ColumnDataSource(data)

columns = [
        TableColumn(field="downloads1", title="1"),
        TableColumn(field="downloads2", title="2"),
        TableColumn(field="downloads3", title="3"),
        TableColumn(field="downloads4", title="4"),
        TableColumn(field="downloads5", title="5"),
        TableColumn(field="downloads6", title="6"),
        TableColumn(field="downloads7", title="7"),
        TableColumn(field="downloads8", title="8"),
        TableColumn(field="downloads9", title="9"),
        TableColumn(field="downloads10", title="10"),
        TableColumn(field="downloads11", title="11"),
        TableColumn(field="downloads12", title="12"),
        TableColumn(field="downloads13", title="13"),
        TableColumn(field="downloads14", title="14"),
        TableColumn(field="downloads15", title="15"),
        TableColumn(field="downloads16", title="16"),
        TableColumn(field="downloads17", title="17"),
        TableColumn(field="downloads18", title="18"),
        TableColumn(field="downloads19", title="19"),
        TableColumn(field="downloads20", title="20"),
        TableColumn(field="downloads21", title="21"),
        TableColumn(field="downloads22", title="22"),
        TableColumn(field="downloads23", title="23"),
        TableColumn(field="downloads24", title="24"),
        TableColumn(field="downloads25", title="25"),
        TableColumn(field="downloads26", title="26"),
        TableColumn(field="downloads27", title="27"),
        TableColumn(field="downloads28", title="28"),
        TableColumn(field="downloads29", title="29"),
        TableColumn(field="downloads30", title="30"),
        TableColumn(field="downloads31", title="31"),
    ]
data_table = DataTable(source=source, columns=columns, width=370, height=190, frozen_columns= 2, sortable= False)

def set_portfolio(attr, old, new):
    # div.text="""LOADING..."""
    ran = (portfolio_no.options.index(portfolio_no.value)) * 100
    ran1 = (portfolio_no.options.index(portfolio_no.value)) * 5000
    data_table.source.data = dict(
            downloads1=[randint(0, ran) for i in range(ran1)],
            downloads2=[randint(0, ran) for i in range(ran1)],
            downloads3=[randint(0, ran) for i in range(ran1)],
            downloads4=[randint(0, ran) for i in range(ran1)],
            downloads5=[randint(0, ran) for i in range(ran1)],
            downloads6=[randint(0, ran) for i in range(ran1)],
            downloads7=[randint(0, ran) for i in range(ran1)],
            downloads8=[randint(0, ran) for i in range(ran1)],
            downloads9=[randint(0, ran) for i in range(ran1)],
            downloads10=[randint(0, ran) for i in range(ran1)],
            downloads11=[randint(0, ran) for i in range(ran1)],
            downloads12=[randint(0, ran) for i in range(ran1)],
            downloads13=[randint(0, ran) for i in range(ran1)],
            downloads14=[randint(0, ran) for i in range(ran1)],
            downloads15=[randint(0, ran) for i in range(ran1)],
            downloads16=[randint(0, ran) for i in range(ran1)],
            downloads17=[randint(0, ran) for i in range(ran1)],
            downloads18=[randint(0, ran) for i in range(ran1)],
            downloads19=[randint(0, ran) for i in range(ran1)],
            downloads20=[randint(0, ran) for i in range(ran1)],
            downloads21=[randint(0, ran) for i in range(ran1)],
            downloads22=[randint(0, ran) for i in range(ran1)],
            downloads23=[randint(0, ran) for i in range(ran1)],
            downloads24=[randint(0, ran) for i in range(ran1)],
            downloads25=[randint(0, ran) for i in range(ran1)],
            downloads26=[randint(0, ran) for i in range(ran1)],
            downloads27=[randint(0, ran) for i in range(ran1)],
            downloads28=[randint(0, ran) for i in range(ran1)],
            downloads29=[randint(0, ran) for i in range(ran1)],
            downloads30=[randint(0, ran) for i in range(ran1)],
            downloads31=[randint(0, ran) for i in range(ran1)]
        )
    # div.text=""""""
# def loading(attr, old, new):
#     div.text="""LOADING..."""
# portfolio_no.on_change("value",loading)
portfolio_no.on_change("value",set_portfolio)
# ticker_data = pdr.get_data_yahoo("SPY", start="2017-01-01", end="2017-04-30")
# ticker_data = pdr.get_data_yahoo('AAPL', start=datetime.datetime(1900, 1, 1), end=datetime.datetime(2022, 1, 1))


def reset2():
    global portfolio_data
    portfolio_data = {"data":[]}
    # div.text="""<img src="https://raw.githubusercontent.com/guangyoung/test2/main/xp.gif" height="20" alt="div_image">"""
    y=0
    while y < 5000:
        # progress1.value = round(len(portfolio_data["data"]),2)
        # data_table.source.data = dict(
        #         downloads1=[],
        #         downloads2=[],
        #         downloads3=[],
        #         downloads4=[],
        #         downloads5=[],
        #         downloads6=[],
        #         downloads7=[],
        #         downloads8=[],
        #         downloads9=[],
        #         downloads10=[],
        #         downloads11=[],
        #         downloads12=[],
        #         downloads13=[],
        #         downloads14=[],
        #         downloads15=[],
        #         downloads16=[],
        #         downloads17=[],
        #         downloads18=[],
        #         downloads19=[],
        #         downloads20=[],
        #         downloads21=[],
        #         downloads22=[],
        #         downloads23=[],
        #         downloads24=[],
        #         downloads25=[],
        #         downloads26=[],
        #         downloads27=[],
        #         downloads28=[],
        #         downloads29=[],
        #         downloads30=[],
        #         downloads31=[]
        #     )
        # progress()
        curdoc().add_next_tick_callback(progress)
        y=y+1
    curdoc().add_next_tick_callback(reset)
    portfolio_data = {"data":[]}

def pretty_float(val):
    if len(repr(val)) > 9:
      return "{:.8e}".format(val)
    else:
      return "{:,.0f}".format(val)

session = CacheControl(requests.Session())
# session = requests.Session()

apiurl = "https://datausa.io/api/data?drilldowns=Nation&measures=Population"
# x=0.0
gbr = "https://raw.githubusercontent.com/guangyoung/test2/main/ai_gif_logo_1_crop.gif"
def progress():
    # portfolio_data = {"data":[]}
    # progress1.value = 0
    # x=0.0
    # c=0.0
    sinyal_color = {"sinyal":[],"color":[]}
    for x in range(30):
        if (randint(0, 10) % 2) == 0:
            sinyal_color["sinyal"].append("BUY")
            sinyal_color["color"].append('#40ff00')
        else:
            sinyal_color["sinyal"].append("SELL")
            sinyal_color["color"].append('#ff0000')
    response = session.get(apiurl)
    portfolio_data["data"].append(response.json())
    div.text = template.format(filee=gbr,
                               value1 = pretty_float(round(len(portfolio_data["data"]),2)+1145151514155),
                               value2 = sinyal_color["sinyal"][0],
                               value211 = sinyal_color["color"][0],
                               value3 = pretty_float(round(len(portfolio_data["data"]),2)+141481514),
                               value4 = sinyal_color["sinyal"][1],
                               value411 = sinyal_color["color"][1],
                               value5 = round(len(portfolio_data["data"]),2),
                               value6 = sinyal_color["sinyal"][2],
                               value611 = sinyal_color["color"][2],
                               value7 = round(len(portfolio_data["data"]),2),
                               value8 = sinyal_color["sinyal"][3],
                               value811 = sinyal_color["color"][3],
                               value9 = round(len(portfolio_data["data"]),2),
                               value10 = sinyal_color["sinyal"][4],
                               value1011 = sinyal_color["color"][4],
                               value11 = round(len(portfolio_data["data"]),2),
                               value12 = sinyal_color["sinyal"][5],
                               value1211 = sinyal_color["color"][5],
                               value13 = round(len(portfolio_data["data"]),2),
                               value14 = sinyal_color["sinyal"][6],
                               value1411 = sinyal_color["color"][6],
                               value15 = round(len(portfolio_data["data"]),2),
                               value16 = sinyal_color["sinyal"][7],
                               value1611 = sinyal_color["color"][7],
                               value17 = round(len(portfolio_data["data"]),2),
                               value18 = sinyal_color["sinyal"][8],
                               value1811 = sinyal_color["color"][8],
                               value19 = round(len(portfolio_data["data"]),2),
                               value20 = sinyal_color["sinyal"][9],
                               value2011 = sinyal_color["color"][9],
                               value21 = round(len(portfolio_data["data"]),2),
                               value22 = sinyal_color["sinyal"][10],
                               value2211 = sinyal_color["color"][10],
                               value23 = round(len(portfolio_data["data"]),2),
                               value24 = sinyal_color["sinyal"][11],
                               value2411 = sinyal_color["color"][11],
                               value25 = round(len(portfolio_data["data"]),2),
                               value26 = sinyal_color["sinyal"][12],
                               value2611 = sinyal_color["color"][12],
                               value27 = round(len(portfolio_data["data"]),2),
                               value28 = sinyal_color["sinyal"][13],
                               value2811 = sinyal_color["color"][13],
                               value29 = round(len(portfolio_data["data"]),2),
                               value30 = sinyal_color["sinyal"][14],
                               value3011 = sinyal_color["color"][14],
                               value31 = round(len(portfolio_data["data"]),2),
                               value32 = sinyal_color["sinyal"][15],
                               value3211 = sinyal_color["color"][15],
                               value33 = round(len(portfolio_data["data"]),2),
                               value34 = sinyal_color["sinyal"][16],
                               value3411 = sinyal_color["color"][16],
                               value35 = round(len(portfolio_data["data"]),2),
                               value36 = sinyal_color["sinyal"][17],
                               value3611 = sinyal_color["color"][17],
                               value37 = round(len(portfolio_data["data"]),2),
                               value38 = sinyal_color["sinyal"][18],
                               value3811 = sinyal_color["color"][18],
                               value39 = round(len(portfolio_data["data"]),2),
                               value40 = sinyal_color["sinyal"][19],
                               value4011 = sinyal_color["color"][19],
                               value41 = round(len(portfolio_data["data"]),2),
                               value42 = sinyal_color["sinyal"][20],
                               value4211 = sinyal_color["color"][20],
                               value43 = round(len(portfolio_data["data"]),2),
                               value44 = sinyal_color["sinyal"][21],
                               value4411 = sinyal_color["color"][21],
                               value45 = round(len(portfolio_data["data"]),2),
                               value46 = sinyal_color["sinyal"][22],
                               value4611 = sinyal_color["color"][22],
                               value47 = round(len(portfolio_data["data"]),2),
                               value48 = sinyal_color["sinyal"][23],
                               value4811 = sinyal_color["color"][23],
                               value49 = round(len(portfolio_data["data"]),2),
                               value50 = sinyal_color["sinyal"][24],
                               value5011 = sinyal_color["color"][24],
                               value51 = round(len(portfolio_data["data"]),2),
                               value52 = sinyal_color["sinyal"][25],
                               value5211 = sinyal_color["color"][25],
                               value53 = round(len(portfolio_data["data"]),2),
                               value54 = sinyal_color["sinyal"][26],
                               value5411 = sinyal_color["color"][26],
                               value55 = round(len(portfolio_data["data"]),2),
                               value56 = sinyal_color["sinyal"][27],
                               value5611 = sinyal_color["color"][27],
                               value57 = round(len(portfolio_data["data"]),2),
                               value58 = sinyal_color["sinyal"][28],
                               value5811 = sinyal_color["color"][28],
                               value59 = round(len(portfolio_data["data"]),2),
                               value60 = sinyal_color["sinyal"][29],
                               value6011 = sinyal_color["color"][29])

    # progress1.value = round(len(portfolio_data["data"]),2)
    # div1.text = template1.format(respon = response.json())
        # print(response)
        # a = 100.0
        # b = 1548425154.2531
        # c = c+(a*b)

    # x = x+1
    # ctypes.windll.user32.MessageBoxExW(0, 'FINISH', 'Selesai', 0x00001000)
    # progress1.value = 0
    # time.sleep(2)
    # reset2()
    # div.text=""""""
    # ran = (portfolio_no.options.index(portfolio_no.value)) * 100
    # ran1 = (portfolio_no.options.index(portfolio_no.value)) * 5000
    # data_table.source.data = dict(
    #         downloads1=[randint(0, ran) for i in range(ran1)],
    #         downloads2=[randint(0, ran) for i in range(ran1)],
    #         downloads3=[randint(0, ran) for i in range(ran1)],
    #         downloads4=[randint(0, ran) for i in range(ran1)],
    #         downloads5=[randint(0, ran) for i in range(ran1)],
    #         downloads6=[randint(0, ran) for i in range(ran1)],
    #         downloads7=[randint(0, ran) for i in range(ran1)],
    #         downloads8=[randint(0, ran) for i in range(ran1)],
    #         downloads9=[randint(0, ran) for i in range(ran1)],
    #         downloads10=[randint(0, ran) for i in range(ran1)],
    #         downloads11=[randint(0, ran) for i in range(ran1)],
    #         downloads12=[randint(0, ran) for i in range(ran1)],
    #         downloads13=[randint(0, ran) for i in range(ran1)],
    #         downloads14=[randint(0, ran) for i in range(ran1)],
    #         downloads15=[randint(0, ran) for i in range(ran1)],
    #         downloads16=[randint(0, ran) for i in range(ran1)],
    #         downloads17=[randint(0, ran) for i in range(ran1)],
    #         downloads18=[randint(0, ran) for i in range(ran1)],
    #         downloads19=[randint(0, ran) for i in range(ran1)],
    #         downloads20=[randint(0, ran) for i in range(ran1)],
    #         downloads21=[randint(0, ran) for i in range(ran1)],
    #         downloads22=[randint(0, ran) for i in range(ran1)],
    #         downloads23=[randint(0, ran) for i in range(ran1)],
    #         downloads24=[randint(0, ran) for i in range(ran1)],
    #         downloads25=[randint(0, ran) for i in range(ran1)],
    #         downloads26=[randint(0, ran) for i in range(ran1)],
    #         downloads27=[randint(0, ran) for i in range(ran1)],
    #         downloads28=[randint(0, ran) for i in range(ran1)],
    #         downloads29=[randint(0, ran) for i in range(ran1)],
    #         downloads30=[randint(0, ran) for i in range(ran1)],
    #         downloads31=[randint(0, ran) for i in range(ran1)]
    #     )
    # div.text=""""""

def reset():
    div.text = temp_reset
    div1.text = temp1_reset

# button_classify = Button(label="Create Pop-up alert")
# callback = CustomJS(args={}, code='alert("hello!");')
# button_classify.js_on_click(callback)

inputs1 = column(text1, api_key, initial_equity, spread_slippage, commision, interest, background="deepskyblue", width=190)
inputs2 = column(text2, data_source, exchange, portfolio, create_testdata, portfolio_no,background="deepskyblue", width=190)
inputs3 = column(data_table, create_apikey, background="deepskyblue", width=380)
inputs4 = column(div)
inputs5 = column(div)

p1 = figure(width=500, height=210)
p1.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=20, color="navy", alpha=0.5)
tabp1 = TabPanel(child=p1, title="Total Return")

p2 = figure(width=500, height=210)
p2.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], line_width=3, color="navy", alpha=0.5)
tabp2 = TabPanel(child=p2, title="CAGR")

p3 = figure(width=500, height=210)
p3.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], line_width=3, color="navy", alpha=0.5)
tabp3 = TabPanel(child=p3, title="Max DD")

p4 = figure(width=500, height=210)
p4.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], line_width=3, color="navy", alpha=0.5)
tabp4 = TabPanel(child=p4, title="Sharpe")

tab_p = Tabs(tabs=[tabp1, tabp2, tabp3, tabp4])
tab_trade = data_table
tab1 = TabPanel(child=p1, title="Performance Comparison")
tab2 = TabPanel(child=tab_trade, title="Account & Trade Summary")

tt = Tabs(tabs=[tab1, tab2])


# Set up callbacks
def update_comm():
    commision.value = 0.05
    portfolio.value=list(map(str, random.sample(range(1, 20), 5)))

create_testdata.on_click(reset2)
# url= 'https://www.javatpoint.com/python-tutorial'
# print(len(portfolio_data["data"]))
def open_url():
    progress1.value = 0
    # webbrowser.open_new_tab('https://www.javatpoint.com/python-tutorial')
create_apikey.on_click(open_url)

def update_spread(attr, old, new):
    spread_slippage.value = 0.05*commision.value

commision.on_change('value', update_spread)
commision.js_on_change('value', CustomJS(args={}, code='alert("hello!");'))

curdoc().theme = 'dark_minimal'
# curdoc().add_root(row(text1, text2, width=1345, background="darkslategray"))
curdoc().add_root(row(inputs1, inputs2, inputs4, width=1345, background="gray"))
curdoc().add_root(row(inputs3, tt, width=1345))
curdoc().title = "Sliders"
print("end")
# Out:
# end
