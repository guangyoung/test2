# %% [markdown]
# <a href="https://colab.research.google.com/github/guangyoung/test2/blob/main/test5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import requests
from urllib3 import PoolManager
from cachecontrol import CacheControl
# from cachecontrol.caches import FileCache
from bokeh.io import curdoc, show, output_notebook
from bokeh.layouts import column, row, layout
from bokeh.models import ColumnDataSource, CustomJS, Slider, TextInput, DatePicker, PasswordInput, NumericInput, Select, MultiSelect, Button, DataTable, DateFormatter, TableColumn, PreText, Div, TabPanel, Tabs
from bokeh.plotting import figure
from datetime import date
from random import randint
import random, time
import urllib.request
from urllib.request import urlopen
import webbrowser
import asyncio
import nest_asyncio
import ctypes
import tkinter
import tkinter as tk
from tkinter import messagebox

# %%
output_notebook()

# %%
api_key = PasswordInput(title="API Key", placeholder="enter your api key...", width=180)
initial_equity = NumericInput(title="Initial Equity", value=1000000, low=1000000, high=100000000, width=180)
spread_slippage = NumericInput(title="Spread+Slippage", value=0.001, low=0.001, high=0.05, width=180, mode="float")
commision = NumericInput(title="Commision", value=0.001, low=0.001, high=0.05, width=180, mode="float")
interest = NumericInput(title="Interest", value=0.001, low=0.001, high=0.05, width=180, mode="float")
data_source = Select(title="Select Data Source:", value="EOD Historical Data", options=["EOD Historical Data", "Tiingo", "Alpha Vantage", "Twelve Data"], width=180)
exchange = Select(title="Select Exchange:", value="Nasdaq", options=["Nasdaq", "NYSE", "LSE", "Dow"], width=180)
OPTIONS = [("1", "foo1"), ("2", "bar1"), ("3", "baz1"), ("4", "quux1"),("5", "foo2"), ("6", "bar2"), ("7", "baz2"), ("8", "quux2"),("9", "foo3"), ("10", "bar3"), ("11", "baz3"), ("12", "quux3"),("13", "foo4"), ("14", "bar4"), ("15", "baz4"), ("16", "quux4"),("17", "foo5"), ("18", "bar5"), ("19", "baz5"), ("20", "quux5")]
# option_value_random = [randint(1, 20) for i in range(5)]
# option_value_random_str = map(str, option_value_random)
portfolio = MultiSelect(title="Select Stock:", value=list(map(str, random.sample(range(1, 20), 5))), options= OPTIONS, height=100, width=180)
create_testdata = Button(label="Create Testdata", button_type="success")
create_apikey = Button(label="Create Apikey", button_type="success")
portfolio_no = Select(title="Select Portfolio:", value="-", options=["-","001", "002", "003", "004"], width=180)
progress1 = NumericInput(value=0.0, low=0.0, high=10000.0, mode="float")

div = Div(text="""""",width=200, height=30)
div1 = Div(text="""""",width=200, height=30)
# template=("""
#       <div class='content'>
#        <div class='name'> {value1} </div>
#        <div class='name'> {value2} </div>
#        <div class='name'> {value3} </div>
#        <div class='name'> {value4} </div>
#        <div class='name'> {value5} </div>
#        <div class='name'> {value6} </div>
#        <div class='name'> {value7} </div>
#        <div class='name'> {value8} </div>
#        <div class='name'> {value9} </div>
#        <div class='name'> {value10} </div>
#        <div class='name'> {value11} </div>
#        <div class='name'> {value12} </div>
#        <div class='name'> {value13} </div>
#        <div class='name'> {value14} </div>
#        <div class='name'> {value15} </div>
#        <div class='name'> {value16} </div>
#        <div class='name'> {value17} </div>
#        <div class='name'> {value18} </div>
#       </div>
#       """)
template=("""
      <div class='content'>
        <div class="table-report">
            <table>
                <tbody>
                    <tr>
                        <td>barang1</td><td>{value1}</td>
                        <td>barang2</td><td>{value2}</td>
                        <td>barang3</td><td>{value3}</td>
                        <td>barang4</td><td>{value4}</td>
                    </tr>
                    <tr>
                        <td>barang1</td><td>{value5}</td>
                        <td>barang2</td><td>{value6}</td>
                        <td>barang3</td><td>{value7}</td>
                        <td>barang4</td><td>{value8}</td>
                    </tr>
                    <tr>
                        <td>barang1</td><td>{value9}</td>
                        <td>barang2</td><td>{value10}</td>
                        <td>barang3</td><td>{value11}</td>
                        <td>barang4</td><td>{value12}</td>
                    </tr>
                    <tr>
                        <td>barang1</td><td>{value13}</td>
                        <td>barang2</td><td>{value14}</td>
                        <td>barang3</td><td>{value15}</td>
                        <td>barang4</td><td>{value16}</td>
                    </tr>
                    <tr>
                        <td>barang1</td><td>{value17}</td>
                        <td>barang2</td><td>{value18}</td>
                        <td>barang3</td><td>{value19}</td>
                        <td>barang4</td><td>{value20}</td>
                    </tr>
                    <tr>
                        <td>barang1</td><td>{value21}</td>
                        <td>barang2</td><td>{value22}</td>
                        <td>barang3</td><td>{value23}</td>
                        <td>barang4</td><td>{value24}</td>
                    </tr>
                    <tr>
                        <td>barang1</td><td>{value25}</td>
                        <td>barang2</td><td>{value26}</td>
                        <td>barang3</td><td>{value27}</td>
                        <td>barang4</td><td>{value28}</td>
                    </tr>
                    <tr>
                        <td>barang1</td><td>{value29}</td>
                        <td>barang2</td><td>{value30}</td>
                        <td>barang3</td><td>{value31}</td>
                        <td>barang4</td><td>{value32}</td>
                    </tr>
                    <tr>
                        <td>barang1</td><td>{value33}</td>
                        <td>barang2</td><td>{value34}</td>
                        <td>barang3</td><td>{value35}</td>
                        <td>barang4</td><td>{value36}</td>
                    </tr>
                    <tr>
                        <td>barang1</td><td>{value37}</td>
                        <td>barang2</td><td>{value38}</td>
                        <td>barang3</td><td>{value39}</td>
                        <td>barang4</td><td>{value40}</td>
                    </tr>
                    <tr>
                        <td>barang1</td><td>{value41}</td>
                        <td>barang2</td><td>{value42}</td>
                        <td>barang3</td><td>{value43}</td>
                        <td>barang4</td><td>{value44}</td>
                    </tr>
                    <tr>
                        <td>barang1</td><td>{value45}</td>
                        <td>barang2</td><td>{value46}</td>
                        <td>barang3</td><td>{value47}</td>
                        <td>barang4</td><td>{value48}</td>
                    </tr><tr>
                        <td>barang1</td><td>{value49}</td>
                        <td>barang2</td><td>{value50}</td>
                        <td>barang3</td><td>{value51}</td>
                        <td>barang4</td><td>{value52}</td>
                    </tr>
                    <tr>
                        <td>barang1</td><td>{value53}</td>
                        <td>barang2</td><td>{value54}</td>
                        <td>barang3</td><td>{value55}</td>
                        <td>barang4</td><td>{value56}</td>
                    </tr>
                    <tr>
                        <td>barang1</td><td>{value57}</td>
                        <td>barang2</td><td>{value58}</td>
                        <td>barang3</td><td>{value59}</td>
                        <td>barang4</td><td>{value60}</td>
                    </tr>
                </tbody>
            </table>
        </div>
      </div>
      """)

show(api_key)
show(initial_equity)
show(spread_slippage)
show(commision)
show(interest)
show(data_source)
show(exchange)
show(portfolio)
# show(create_testdata)
# input("yakin ?")
# portfolio_no.options.index(portfolio_no.value)
progress1.value
# Out:
#   <div id="ea8dd992-1d44-4d8f-833a-755d675a0d51" data-root-id="p6030" style="display: contents;"></div>
#   <div id="ff710711-9d65-4201-8a46-9ccaf07fc78a" data-root-id="p6031" style="display: contents;"></div>
#   <div id="dbbe1245-39e6-4afc-8358-68387d033d60" data-root-id="p6032" style="display: contents;"></div>
#   <div id="dc94e433-a93f-4733-9680-2532807a2b69" data-root-id="p6033" style="display: contents;"></div>
#   <div id="d38da2d6-1230-4d0f-b7ac-43f3d8298aa5" data-root-id="p6034" style="display: contents;"></div>
#   <div id="c285d211-06f5-495b-9c60-e635e9054d5d" data-root-id="p6035" style="display: contents;"></div>
#   <div id="debeab94-157d-49e5-88bc-c9e0ac616c4a" data-root-id="p6036" style="display: contents;"></div>
#   <div id="d4f5831b-b7d7-43a9-90c1-3f9912ca3e00" data-root-id="p6037" style="display: contents;"></div>
# 0.0

# %%
# Set up data
# N = 200
# x = np.linspace(0, 4*np.pi, N)
# y = np.sin(x)
# source = ColumnDataSource(data=dict(x=x, y=y))


# Set up plot
# plot = figure(height=285, width=350, title="my sine wave",
#               tools="crosshair,pan,reset,save,wheel_zoom",
#               x_range=[0, 4*np.pi], y_range=[-2.5, 2.5])

# plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)


# Set up widgets
# text = PreText(text="""QUANTZENIUS""", width=100, height=12)
text1 = Div(text="""<img src="https://raw.githubusercontent.com/guangyoung/test2/main/logo_quantxi1.png" width="200" height="40" alt="div_image">""")
text2 = Div(text="""<img src="https://raw.githubusercontent.com/guangyoung/test2/main/systemtesting.png" width="200" height="40" alt="div_image">""")
# api_key = PasswordInput(title="API Key", placeholder="enter your api key...", width=180)


# date_picker = DatePicker(
#     title="Select date",
#     value="2019-09-20",
#     min_date="2019-08-01",
#     max_date="2019-10-30",
# )

pre = PreText(text="""TESTDATA""", width=100, height=12)

data = dict(
            downloads1=[],
            downloads2=[],
            downloads3=[],
            downloads4=[],
            downloads5=[],
            downloads6=[],
            downloads7=[],
            downloads8=[],
            downloads9=[],
            downloads10=[],
            downloads11=[],
            downloads12=[],
            downloads13=[],
            downloads14=[],
            downloads15=[],
            downloads16=[],
            downloads17=[],
            downloads18=[],
            downloads19=[],
            downloads20=[],
            downloads21=[],
            downloads22=[],
            downloads23=[],
            downloads24=[],
            downloads25=[],
            downloads26=[],
            downloads27=[],
            downloads28=[],
            downloads29=[],
            downloads30=[],
            downloads31=[]
        )
source = ColumnDataSource(data)

columns = [
        TableColumn(field="downloads1", title="1"),
        TableColumn(field="downloads2", title="2"),
        TableColumn(field="downloads3", title="3"),
        TableColumn(field="downloads4", title="4"),
        TableColumn(field="downloads5", title="5"),
        TableColumn(field="downloads6", title="6"),
        TableColumn(field="downloads7", title="7"),
        TableColumn(field="downloads8", title="8"),
        TableColumn(field="downloads9", title="9"),
        TableColumn(field="downloads10", title="10"),
        TableColumn(field="downloads11", title="11"),
        TableColumn(field="downloads12", title="12"),
        TableColumn(field="downloads13", title="13"),
        TableColumn(field="downloads14", title="14"),
        TableColumn(field="downloads15", title="15"),
        TableColumn(field="downloads16", title="16"),
        TableColumn(field="downloads17", title="17"),
        TableColumn(field="downloads18", title="18"),
        TableColumn(field="downloads19", title="19"),
        TableColumn(field="downloads20", title="20"),
        TableColumn(field="downloads21", title="21"),
        TableColumn(field="downloads22", title="22"),
        TableColumn(field="downloads23", title="23"),
        TableColumn(field="downloads24", title="24"),
        TableColumn(field="downloads25", title="25"),
        TableColumn(field="downloads26", title="26"),
        TableColumn(field="downloads27", title="27"),
        TableColumn(field="downloads28", title="28"),
        TableColumn(field="downloads29", title="29"),
        TableColumn(field="downloads30", title="30"),
        TableColumn(field="downloads31", title="31"),
    ]
data_table = DataTable(source=source, columns=columns, width=600, height=268, frozen_columns= 2, sortable= False)

def set_portfolio(attr, old, new):
    # div.text="""LOADING..."""
    ran = (portfolio_no.options.index(portfolio_no.value)) * 100
    ran1 = (portfolio_no.options.index(portfolio_no.value)) * 5000
    data_table.source.data = dict(
            downloads1=[randint(0, ran) for i in range(ran1)],
            downloads2=[randint(0, ran) for i in range(ran1)],
            downloads3=[randint(0, ran) for i in range(ran1)],
            downloads4=[randint(0, ran) for i in range(ran1)],
            downloads5=[randint(0, ran) for i in range(ran1)],
            downloads6=[randint(0, ran) for i in range(ran1)],
            downloads7=[randint(0, ran) for i in range(ran1)],
            downloads8=[randint(0, ran) for i in range(ran1)],
            downloads9=[randint(0, ran) for i in range(ran1)],
            downloads10=[randint(0, ran) for i in range(ran1)],
            downloads11=[randint(0, ran) for i in range(ran1)],
            downloads12=[randint(0, ran) for i in range(ran1)],
            downloads13=[randint(0, ran) for i in range(ran1)],
            downloads14=[randint(0, ran) for i in range(ran1)],
            downloads15=[randint(0, ran) for i in range(ran1)],
            downloads16=[randint(0, ran) for i in range(ran1)],
            downloads17=[randint(0, ran) for i in range(ran1)],
            downloads18=[randint(0, ran) for i in range(ran1)],
            downloads19=[randint(0, ran) for i in range(ran1)],
            downloads20=[randint(0, ran) for i in range(ran1)],
            downloads21=[randint(0, ran) for i in range(ran1)],
            downloads22=[randint(0, ran) for i in range(ran1)],
            downloads23=[randint(0, ran) for i in range(ran1)],
            downloads24=[randint(0, ran) for i in range(ran1)],
            downloads25=[randint(0, ran) for i in range(ran1)],
            downloads26=[randint(0, ran) for i in range(ran1)],
            downloads27=[randint(0, ran) for i in range(ran1)],
            downloads28=[randint(0, ran) for i in range(ran1)],
            downloads29=[randint(0, ran) for i in range(ran1)],
            downloads30=[randint(0, ran) for i in range(ran1)],
            downloads31=[randint(0, ran) for i in range(ran1)]
        )
    # div.text=""""""
# def loading(attr, old, new):
#     div.text="""LOADING..."""
# portfolio_no.on_change("value",loading)
portfolio_no.on_change("value",set_portfolio)
# ticker_data = pdr.get_data_yahoo("SPY", start="2017-01-01", end="2017-04-30")
# ticker_data = pdr.get_data_yahoo('AAPL', start=datetime.datetime(1900, 1, 1), end=datetime.datetime(2022, 1, 1))


def reset2():
    global portfolio_data
    portfolio_data = {"data":[]}
    # div.text="""<img src="https://raw.githubusercontent.com/guangyoung/test2/main/xp.gif" height="20" alt="div_image">"""
    y=0
    while y < 1000:
        # progress1.value = round(len(portfolio_data["data"]),2)
        # data_table.source.data = dict(
        #         downloads1=[],
        #         downloads2=[],
        #         downloads3=[],
        #         downloads4=[],
        #         downloads5=[],
        #         downloads6=[],
        #         downloads7=[],
        #         downloads8=[],
        #         downloads9=[],
        #         downloads10=[],
        #         downloads11=[],
        #         downloads12=[],
        #         downloads13=[],
        #         downloads14=[],
        #         downloads15=[],
        #         downloads16=[],
        #         downloads17=[],
        #         downloads18=[],
        #         downloads19=[],
        #         downloads20=[],
        #         downloads21=[],
        #         downloads22=[],
        #         downloads23=[],
        #         downloads24=[],
        #         downloads25=[],
        #         downloads26=[],
        #         downloads27=[],
        #         downloads28=[],
        #         downloads29=[],
        #         downloads30=[],
        #         downloads31=[]
        #     )
        # progress()
        curdoc().add_next_tick_callback(progress)
        y=y+1
    portfolio_data = {"data":[]}

session = CacheControl(requests.Session())
# session = requests.Session()

apiurl = "https://datausa.io/api/data?drilldowns=Nation&measures=Population"
# x=0.0
def progress():
    # portfolio_data = {"data":[]}
    # progress1.value = 0
    # x=0.0
    # c=0.0
    sinyal = "HOLD"
    sinyal1 = "HOLD"
    if (randint(0, 10) % 2) == 0:
        sinyal = "BUY"
    else:
        sinyal = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal1 = "BUY"
    else:
        sinyal1 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal2 = "BUY"
    else:
        sinyal2 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal3 = "BUY"
    else:
        sinyal3 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal4 = "BUY"
    else:
        sinyal4 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal5 = "BUY"
    else:
        sinyal5 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal6 = "BUY"
    else:
        sinyal6 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal7 = "BUY"
    else:
        sinyal7 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal8 = "BUY"
    else:
        sinyal8 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal9 = "BUY"
    else:
        sinyal9 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal10 = "BUY"
    else:
        sinyal10 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal11 = "BUY"
    else:
        sinyal11 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal12 = "BUY"
    else:
        sinyal12 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal13 = "BUY"
    else:
        sinyal13 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal14 = "BUY"
    else:
        sinyal14 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal15 = "BUY"
    else:
        sinyal15 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal16 = "BUY"
    else:
        sinyal16 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal17 = "BUY"
    else:
        sinyal17 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal18 = "BUY"
    else:
        sinyal18 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal19 = "BUY"
    else:
        sinyal19 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal20 = "BUY"
    else:
        sinyal20 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal21 = "BUY"
    else:
        sinyal21 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal22 = "BUY"
    else:
        sinyal22 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal23 = "BUY"
    else:
        sinyal23 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal24 = "BUY"
    else:
        sinyal24 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal25 = "BUY"
    else:
        sinyal25 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal26 = "BUY"
    else:
        sinyal26 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal27 = "BUY"
    else:
        sinyal27 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal28 = "BUY"
    else:
        sinyal28 = "SELL"
    if (randint(0, 10) % 2) == 0:
        sinyal29 = "BUY"
    else:
        sinyal29 = "SELL"
    div.text = template.format(value1 = round(len(portfolio_data["data"]),2),
                               value2 = sinyal,
                               value3 = round(len(portfolio_data["data"]),2),
                               value4 = sinyal1,
                               value5 = round(len(portfolio_data["data"]),2),
                               value6 = sinyal2,
                               value7 = round(len(portfolio_data["data"]),2),
                               value8 = sinyal3,
                               value9 = round(len(portfolio_data["data"]),2),
                               value10 = sinyal4,
                               value11 = round(len(portfolio_data["data"]),2),
                               value12 = sinyal5,
                               value13 = round(len(portfolio_data["data"]),2),
                               value14 = sinyal6,
                               value15 = round(len(portfolio_data["data"]),2),
                               value16 = sinyal7,
                               value17 = round(len(portfolio_data["data"]),2),
                               value18 = sinyal8,
                               value19 = round(len(portfolio_data["data"]),2),
                               value20 = sinyal9,
                               value21 = round(len(portfolio_data["data"]),2),
                               value22 = sinyal10,
                               value23 = round(len(portfolio_data["data"]),2),
                               value24 = sinyal11,
                               value25 = round(len(portfolio_data["data"]),2),
                               value26 = sinyal12,
                               value27 = round(len(portfolio_data["data"]),2),
                               value28 = sinyal13,
                               value29 = round(len(portfolio_data["data"]),2),
                               value30 = sinyal14,
                               value31 = round(len(portfolio_data["data"]),2),
                               value32 = sinyal15,
                               value33 = round(len(portfolio_data["data"]),2),
                               value34 = sinyal16,
                               value35 = round(len(portfolio_data["data"]),2),
                               value36 = sinyal17,
                               value37 = round(len(portfolio_data["data"]),2),
                               value38 = sinyal18,
                               value39 = round(len(portfolio_data["data"]),2),
                               value40 = sinyal19,
                               value41 = round(len(portfolio_data["data"]),2),
                               value42 = sinyal20,
                               value43 = round(len(portfolio_data["data"]),2),
                               value44 = sinyal21,
                               value45 = round(len(portfolio_data["data"]),2),
                               value46 = sinyal22,
                               value47 = round(len(portfolio_data["data"]),2),
                               value48 = sinyal23,
                               value49 = round(len(portfolio_data["data"]),2),
                               value50 = sinyal24,
                               value51 = round(len(portfolio_data["data"]),2),
                               value52 = sinyal25,
                               value53 = round(len(portfolio_data["data"]),2),
                               value54 = sinyal26,
                               value55 = round(len(portfolio_data["data"]),2),
                               value56 = sinyal27,
                               value57 = round(len(portfolio_data["data"]),2),
                               value58 = sinyal28,
                               value59 = round(len(portfolio_data["data"]),2),
                               value60 = sinyal29)
    # progress1.value = round(len(portfolio_data["data"]),2)
    response = session.get(apiurl)
    portfolio_data["data"].append(response.json())
        # print(response)
        # a = 100.0
        # b = 1548425154.2531
        # c = c+(a*b)

    # x = x+1
    # ctypes.windll.user32.MessageBoxExW(0, 'FINISH', 'Selesai', 0x00001000)
    # progress1.value = 0
    # time.sleep(2)
    # reset2()
    # div.text=""""""
    # ran = (portfolio_no.options.index(portfolio_no.value)) * 100
    # ran1 = (portfolio_no.options.index(portfolio_no.value)) * 5000
    # data_table.source.data = dict(
    #         downloads1=[randint(0, ran) for i in range(ran1)],
    #         downloads2=[randint(0, ran) for i in range(ran1)],
    #         downloads3=[randint(0, ran) for i in range(ran1)],
    #         downloads4=[randint(0, ran) for i in range(ran1)],
    #         downloads5=[randint(0, ran) for i in range(ran1)],
    #         downloads6=[randint(0, ran) for i in range(ran1)],
    #         downloads7=[randint(0, ran) for i in range(ran1)],
    #         downloads8=[randint(0, ran) for i in range(ran1)],
    #         downloads9=[randint(0, ran) for i in range(ran1)],
    #         downloads10=[randint(0, ran) for i in range(ran1)],
    #         downloads11=[randint(0, ran) for i in range(ran1)],
    #         downloads12=[randint(0, ran) for i in range(ran1)],
    #         downloads13=[randint(0, ran) for i in range(ran1)],
    #         downloads14=[randint(0, ran) for i in range(ran1)],
    #         downloads15=[randint(0, ran) for i in range(ran1)],
    #         downloads16=[randint(0, ran) for i in range(ran1)],
    #         downloads17=[randint(0, ran) for i in range(ran1)],
    #         downloads18=[randint(0, ran) for i in range(ran1)],
    #         downloads19=[randint(0, ran) for i in range(ran1)],
    #         downloads20=[randint(0, ran) for i in range(ran1)],
    #         downloads21=[randint(0, ran) for i in range(ran1)],
    #         downloads22=[randint(0, ran) for i in range(ran1)],
    #         downloads23=[randint(0, ran) for i in range(ran1)],
    #         downloads24=[randint(0, ran) for i in range(ran1)],
    #         downloads25=[randint(0, ran) for i in range(ran1)],
    #         downloads26=[randint(0, ran) for i in range(ran1)],
    #         downloads27=[randint(0, ran) for i in range(ran1)],
    #         downloads28=[randint(0, ran) for i in range(ran1)],
    #         downloads29=[randint(0, ran) for i in range(ran1)],
    #         downloads30=[randint(0, ran) for i in range(ran1)],
    #         downloads31=[randint(0, ran) for i in range(ran1)]
    #     )
    # div.text=""""""

# def reset():
#     div.text=""""""

# button_classify = Button(label="Create Pop-up alert")
# callback = CustomJS(args={}, code='alert("hello!");')
# button_classify.js_on_click(callback)

inputs1 = column(api_key, initial_equity, spread_slippage, commision, interest)
inputs2 = column(create_apikey, data_source, exchange, portfolio, create_testdata)
inputs3 = column(portfolio_no, data_table)
inputs4 = column(div)

p1 = figure(width=500, height=240)
p1.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=20, color="navy", alpha=0.5)
tab1 = TabPanel(child=p1, title="Total Return")

p2 = figure(width=500, height=240)
p2.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], line_width=3, color="navy", alpha=0.5)
tab2 = TabPanel(child=p2, title="CAGR")

p3 = figure(width=500, height=240)
p3.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], line_width=3, color="navy", alpha=0.5)
tab3 = TabPanel(child=p3, title="Max DD")

inputs10 = row(inputs1, inputs2, width=370, background="gray")
tab4 = TabPanel(child=inputs10, title="Sharpe")

tt1 = Tabs(tabs=[tab1, tab2, tab3, tab4])
tab5 = TabPanel(child=tt1, title="Sharpe")

tt = Tabs(tabs=[tab5, tab2, tab3, tab4])


# Set up callbacks
def update_comm():
    commision.value = 0.05
    portfolio.value=list(map(str, random.sample(range(1, 20), 5)))

create_testdata.on_click(reset2)
# url= 'https://www.javatpoint.com/python-tutorial'
# print(len(portfolio_data["data"]))
def open_url():
    progress1.value = 0
    # webbrowser.open_new_tab('https://www.javatpoint.com/python-tutorial')
create_apikey.on_click(open_url)

def update_spread(attr, old, new):
    spread_slippage.value = 0.05*commision.value

commision.on_change('value', update_spread)
commision.js_on_change('value', CustomJS(args={}, code='alert("hello!");'))

curdoc().theme = 'dark_minimal'
curdoc().add_root(row(text1, text2, width=1360, background="darkslategray"))
curdoc().add_root(row(inputs1, inputs2, inputs3, inputs4, width=1360, background="gray"))
curdoc().add_root(row(tt, width=1360, height=300, background="deepskyblue"))
curdoc().title = "Sliders"
print("end")
# Out:
# end
